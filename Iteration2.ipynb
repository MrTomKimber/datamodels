# %%
import owlready2 as owlr
import pandas as pd
from rdflib import URIRef, Literal, Graph
from rdflib.namespace import RDF, RDFS
from rdflib import Namespace
from rdflib.extras.external_graph_libs import rdflib_to_networkx_multidigraph

from collections import Counter
import uuid

import io
import pydotplus
from IPython.display import display, Image
from rdflib.tools.rdf2dot import rdf2dot
from IPython.core.display import HTML

def visualize(g):
    stream = io.StringIO()
    rdf2dot(g, stream, opts = {display})
    dg = pydotplus.graph_from_dot_data(stream.getvalue())
    png = dg.create_png()

    display(Image(png))


    
    
    
    
import networkx as nx


import loader
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
raw_world = owlr.World(filename='raw_world.sqlite3')
rawdms = raw_world.get_ontology("datamodels_rdf.owl").load()
onto = rawdms
with onto:
    owlr.sync_reasoner(raw_world)
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /usr/local/python/py36/lib/python3.6/site-packages/owlready2/hermit:/usr/local/python/py36/lib/python3.6/site-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////var/folders/rd/q3bhk6_n56x75m05pp2sq7dr0000gn/T/tmpcsqndhrt
# * Owlready2 * HermiT took 0.7251420021057129 seconds
# * Owlready * Reparenting datamodels_rdf.IdentityClassParentModel: {datamodels_rdf.IdentityParent, owl.ObjectProperty} => {datamodels_rdf.IdentityParent}
# * Owlready * Reparenting datamodels_rdf.ModelDomainContainsModel: {datamodels_rdf.HierarchicalRelations, owl.ObjectProperty} => {datamodels_rdf.HierarchicalRelations}
# * Owlready * Reparenting datamodels_rdf.ClassHasAttribute: {datamodels_rdf.HierarchicalRelations, owl.ObjectProperty} => {datamodels_rdf.HierarchicalRelations}
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
onto_dataproperties = list(onto.data_properties())
onto_individuals = list (onto.individuals())
individuals = [(i, i.is_a.first()) for i in onto_individuals + onto_dataproperties]
serializations = [i[0] for i in individuals if i[1] == onto.Serialization]

serialization_mappings={}
for s in serializations:
    print(s)

    mappings = [m for m in s.SerializationContainsMapping] 
    serialization_mappings[s.name]=mappings
    # Danger!! For multiple mappings, this fails!
    
serialization_mappings
# Out:
# datamodels_rdf.EntityAttributeRecord
# datamodels_rdf.RelationshipRecord
# {'EntityAttributeRecord': [datamodels_rdf.AttributeMapping,
#   datamodels_rdf.ClassMapping,
#   datamodels_rdf.DomainMapping,
#   datamodels_rdf.ModelMapping,
#   datamodels_rdf.hasAttributeMapping,
#   datamodels_rdf.hasClassMapping,
#   datamodels_rdf.hasDataTypeMapping,
#   datamodels_rdf.hasModelMapping,
#   datamodels_rdf.hasModelTypeMapping],
#  'RelationshipRecord': [datamodels_rdf.DomainMapping,
#   datamodels_rdf.ModelMapping,
#   datamodels_rdf.RelationshipMapping,
#   datamodels_rdf.hasModelTypeMapping,
#   datamodels_rdf.hasRelationshipDomainMapping,
#   datamodels_rdf.hasRelationshipFromCardinalityMapping,
#   datamodels_rdf.hasRelationshipFromOptionalityMapping,
#   datamodels_rdf.hasRelationshipKeyFromMapping,
#   datamodels_rdf.hasRelationshipKeyToMapping,
#   datamodels_rdf.hasRelationshipMapping,
#   datamodels_rdf.hasRelationshipRangeMapping,
#   datamodels_rdf.hasRelationshipToCardinalityMapping,
#   datamodels_rdf.hasRelationshipToOptionalityMapping]}

# %%
mapped_things = [(c,c.MappingKey,"class") for c in onto.classes() if len(c.MappingKey) > 0] + \
                [(p, p.MappingKey,"data") for p in onto.data_properties() if len(p.MappingKey) > 0] + \
                [(p, p.MappingKey,"object") for p in onto.object_properties() if len(p.MappingKey) > 0] 
mappable_things = {vv:k for k,v,t in mapped_things for vv in v}
mappable_things_ext = {vv:(k,t) for k,v,t in mapped_things for vv in v}
assert all([v==1 for v in Counter([b for c in mapped_things for b in c[1]]).values()])
#del mapped_things
#mappable_things
mappable_things_ext

row_node_class = [c for c in onto.classes() if c.name == 'RowNode']
row_node_participant = [p for p in onto.properties() if p.name == 'RowNodeParticipant']
row_node_class, row_node_participant
mappable_things_ext
# Out:
# {'Class': (datamodels_rdf.Class, 'class'),
#  'Attribute': (datamodels_rdf.Attribute, 'class'),
#  'Relationship': (datamodels_rdf.Relationship, 'class'),
#  'DataModel': (datamodels_rdf.DataModel, 'class'),
#  'Domain': (datamodels_rdf.ModelDomain, 'class'),
#  'isRowNode': (datamodels_rdf.RowNode, 'class'),
#  'Serialization': (datamodels_rdf.Serialization, 'class'),
#  'Mapping': (datamodels_rdf.Mapping, 'class'),
#  'Context': (datamodels_rdf.Context, 'class'),
#  'hasCardinality': (datamodels_rdf.Cardinality, 'data'),
#  'hasOptionality': (datamodels_rdf.Optionality, 'data'),
#  'DataType': (datamodels_rdf.DataType, 'data'),
#  'hasDataType': (datamodels_rdf.DataType, 'data'),
#  'ModelType': (datamodels_rdf.ModelType, 'data'),
#  'hasModelType': (datamodels_rdf.ModelType, 'data'),
#  'hasModelType_obsolete': (datamodels_rdf.ModelTypeCode, 'data'),
#  'UniqueIdentifier': (datamodels_rdf.UniqueIdentifier, 'data'),
#  'hasAttribute': (datamodels_rdf.ClassHasAttribute, 'object'),
#  'hasRelationshipDomain': (datamodels_rdf.RelationshipHasDomain, 'object'),
#  'hasRelationshipRange': (datamodels_rdf.RelationshipHasRange, 'object'),
#  'hasClass': (datamodels_rdf.ModelContainsClass, 'object'),
#  'isAttributeParent': (datamodels_rdf.IdentityAttributeParentClass, 'object'),
#  'isClassParent': (datamodels_rdf.IdentityClassParentModel, 'object'),
#  'isRelationshipParent': (datamodels_rdf.IdentityRelationshipParentModel,
#   'object'),
#  'hasRelationship': (datamodels_rdf.ModelContainsRelationship, 'object'),
#  'hasModel': (datamodels_rdf.ModelDomainContainsModel, 'object'),
#  'hasRelationshipKeyFromAttribute': (datamodels_rdf.RelationshipKeyFromAttribute,
#   'object'),
#  'hasRelationshipKeyToAttribute': (datamodels_rdf.RelationshipKeyToAttribute,
#   'object'),
#  'isParticipant': (datamodels_rdf.RowNodeParticipant, 'object')}

# %%
mapping_data = {}
for s in serializations:
    mapping_data[s.name]={}
    mappings = [m for m in s.SerializationContainsMapping] 
    for m in mappings:
        mapping_data[s.name][m.name]={}
        for p in m.get_properties():
            mapping_data[s.name][m.name][p.name]=p[m].first()
mapping_data
# Out:
# {'EntityAttributeRecord': {'AttributeMapping': {'MappingRange': 'Attribute',
#    'SerializationLabel': 'Attribute',
#    'MappingLabel': 'Attribute',
#    'MappingSubType': 'Entity'},
#   'ClassMapping': {'MappingRange': 'Class',
#    'SerializationLabel': 'Entity',
#    'MappingLabel': 'Class',
#    'MappingSubType': 'Entity'},
#   'DomainMapping': {'MappingRange': 'Domain',
#    'SerializationLabel': 'Business Domain',
#    'MappingLabel': 'Domain',
#    'MappingSubType': 'Entity'},
#   'ModelMapping': {'MappingRange': 'DataModel',
#    'SerializationLabel': 'Model',
#    'MappingLabel': 'DataModel',
#    'MappingSubType': 'Entity'},
#   'hasAttributeMapping': {'SerializationLabel': 'Attribute',
#    'MappingLabel': 'hasAttribute',
#    'MappingRange': 'Attribute',
#    'MappingDomain': 'Class',
#    'MappingSubType': 'Property'},
#   'hasClassMapping': {'SerializationLabel': 'Entity',
#    'MappingLabel': 'hasClass',
#    'MappingRange': 'Class',
#    'MappingDomain': 'DataModel',
#    'MappingSubType': 'Property'},
#   'hasDataTypeMapping': {'SerializationLabel': 'DataType',
#    'MappingLabel': 'hasDataType',
#    'MappingRange': 'DataType',
#    'MappingDomain': 'Attribute',
#    'MappingSubType': 'Property'},
#   'hasModelMapping': {'SerializationLabel': 'Model',
#    'MappingLabel': 'hasModel',
#    'MappingRange': 'DataModel',
#    'MappingDomain': 'Domain',
#    'MappingSubType': 'Property'},
#   'hasModelTypeMapping': {'SerializationLabel': 'ModelType',
#    'MappingLabel': 'hasModelType',
#    'MappingRange': 'ModelType',
#    'MappingDomain': 'DataModel',
#    'MappingSubType': 'Property'}},
#  'RelationshipRecord': {'DomainMapping': {'MappingRange': 'Domain',
#    'SerializationLabel': 'Business Domain',
#    'MappingLabel': 'Domain',
#    'MappingSubType': 'Entity'},
#   'ModelMapping': {'MappingRange': 'DataModel',
#    'SerializationLabel': 'Model',
#    'MappingLabel': 'DataModel',
#    'MappingSubType': 'Entity'},
#   'RelationshipMapping': {'MappingRange': 'Relationship',
#    'SerializationLabel': 'Relationship',
#    'MappingLabel': 'Relationship',
#    'MappingSubType': 'Entity'},
#   'hasModelTypeMapping': {'SerializationLabel': 'ModelType',
#    'MappingLabel': 'hasModelType',
#    'MappingRange': 'ModelType',
#    'MappingDomain': 'DataModel',
#    'MappingSubType': 'Property'},
#   'hasRelationshipDomainMapping': {'SerializationLabel': 'FromClass',
#    'MappingLabel': 'hasRelationshipDomain',
#    'MappingRange': 'Class',
#    'MappingDomain': 'Relationship',
#    'MappingSubType': 'Property'},
#   'hasRelationshipFromCardinalityMapping': {'SerializationLabel': 'FromCardinality',
#    'MappingLabel': 'hasCardinality',
#    'MappingRange': 'Cardinality',
#    'MappingDomain': 'Relationship',
#    'MappingSubType': 'Property'},
#   'hasRelationshipFromOptionalityMapping': {'SerializationLabel': 'FromOptionality',
#    'MappingLabel': 'hasOptionality',
#    'MappingRange': 'Optionality',
#    'MappingDomain': 'Relationship',
#    'MappingSubType': 'Property'},
#   'hasRelationshipKeyFromMapping': {'SerializationLabel': 'FromAttribute',
#    'MappingLabel': 'hasRelationshipKeyFromAttribute',
#    'MappingRange': 'Attribute',
#    'MappingDomain': 'Relationship',
#    'MappingSubType': 'Property'},
#   'hasRelationshipKeyToMapping': {'SerializationLabel': 'ToAttribute',
#    'MappingLabel': 'hasRelationshipKeyToAttribute',
#    'MappingRange': 'Attribute',
#    'MappingDomain': 'Relationship',
#    'MappingSubType': 'Property'},
#   'hasRelationshipMapping': {'SerializationLabel': 'Relationship',
#    'MappingLabel': 'hasRelationship',
#    'MappingRange': 'Relationship',
#    'MappingDomain': 'DataModel',
#    'MappingSubType': 'Property'},
#   'hasRelationshipRangeMapping': {'SerializationLabel': 'ToClass',
#    'MappingLabel': 'hasRelationshipRange',
#    'MappingRange': 'Class',
#    'MappingDomain': 'Relationship',
#    'MappingSubType': 'Property'},
#   'hasRelationshipToCardinalityMapping': {'SerializationLabel': 'ToCardinality',
#    'MappingLabel': 'hasCardinality',
#    'MappingRange': 'Cardinality',
#    'MappingDomain': 'Relationship',
#    'MappingSubType': 'Property'},
#   'hasRelationshipToOptionalityMapping': {'SerializationLabel': 'ToOptionality',
#    'MappingLabel': 'hasOptionality',
#    'MappingRange': 'Optionality',
#    'MappingDomain': 'Relationship',
#    'MappingSubType': 'Property'}}}

# %%
data_rows = [{ "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Person", 
             "Attribute" : "PersonID", 
             "DataType" : "string"}, 
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Person", 
             "Attribute" : "FirstName", 
             "DataType" : "string"}, 
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Person", 
             "Attribute" : "FamilyName", 
             "DataType" : "string"}, 
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Person", 
             "Attribute" : "DateOfBirth", 
             "DataType" : "date"}, 
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Person", 
             "Attribute" : "DateOfDeath", 
             "DataType" : "date"}, 
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Address", 
             "Attribute" : "Address Line 1", 
             "DataType" : "string"}, 
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Address", 
             "Attribute" : "Address Line 2", 
             "DataType" : "string"}, 
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Address", 
             "Attribute" : "Address Line 3", 
             "DataType" : "string"}, 
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Address", 
             "Attribute" : "Postal Code", 
             "DataType" : "string"}, 
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Address", 
             "Attribute" : "Country", 
             "DataType" : "string"}, 
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Address", 
             "Attribute" : "Country", 
             "DataType" : "string"},
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Insurance Product", 
             "Attribute" : "Coverage Type", 
             "DataType" : "string"},
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Insurance Policy", 
             "Attribute" : "Policy ID", 
             "DataType" : "string"},
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Insurance Policy", 
             "Attribute" : "Start Date", 
             "DataType" : "string"},
            { "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Entity" : "Insurance Policy", 
             "Attribute" : "End Date", 
             "DataType" : "string"},
             
            ]

pd.DataFrame(data_rows)
# Out:
#    Business Domain                   Model   ModelType             Entity  \
# 0             Core  Principal Interactions  Conceptual             Person
# 1             Core  Principal Interactions  Conceptual             Person
# 2             Core  Principal Interactions  Conceptual             Person
# 3             Core  Principal Interactions  Conceptual             Person
# 4             Core  Principal Interactions  Conceptual             Person
# 5             Core  Principal Interactions  Conceptual            Address
# 6             Core  Principal Interactions  Conceptual            Address
# 7             Core  Principal Interactions  Conceptual            Address
# 8             Core  Principal Interactions  Conceptual            Address
# 9             Core  Principal Interactions  Conceptual            Address
# 10            Core  Principal Interactions  Conceptual            Address
# 11            Core  Principal Interactions  Conceptual  Insurance Product
# 12            Core  Principal Interactions  Conceptual   Insurance Policy
# 13            Core  Principal Interactions  Conceptual   Insurance Policy
# 14            Core  Principal Interactions  Conceptual   Insurance Policy
#
#          Attribute DataType
# 0         PersonID   string
# 1        FirstName   string
# 2       FamilyName   string
# 3      DateOfBirth     date
# 4      DateOfDeath     date
# 5   Address Line 1   string
# 6   Address Line 2   string
# 7   Address Line 3   string
# 8      Postal Code   string
# 9          Country   string
# 10         Country   string
# 11   Coverage Type   string
# 12       Policy ID   string
# 13      Start Date   string
# 14        End Date   string

# %%
staging_graph = Graph()

# %%
q="""SELECT distinct ?s ?o
WHERE

{
    {?s ?p ?o .
     # ?h rdfs:subPropertyOf dm:HierarchicalRelations.
     BIND (dm:UniqueIdentifier as ?p)
     # ?s dm:UniqueIdentifier ?o .
     FILTER NOT EXISTS {?s rdf:type dm:RowNode . }
     }
     
}
 
 """


for e,r in enumerate(data_rows):
    m_data = mapping_data['EntityAttributeRecord']
    row_graph_triples = loader.gen_temp_entity_triples_from_row(m_data, mappable_things_ext, "http://temp", r, row_id=f'row_{e}')
    row_graph=Graph()
    for t in row_graph_triples:
        row_graph.add(t)
    # connect additional context to row-graph
    row_graph.parse ("datamodels_rdf.owl", format='xml')
    dmns = Namespace(onto.base_iri)
    row_graph.bind('dm', dmns)
    row_graph.bind('rdfs', RDFS)
    namespace_d = {'dm': dmns, 'rdfs' : RDFS, 'rdf' : RDF}
    unique_id_triples=loader.gen_unique_identity_triples(row_graph, namespace_d)
    for t in unique_id_triples:
        row_graph.add(t)
        
    #{dir(k):v for k,v in list(row_graph.query(q, initNs={'dm': dmns, 'rdfs' : RDFS, 'rdf' : RDF}))}

    row_object_keys_d = {v.value:k.n3()[1:-1] for k,v in list(row_graph.query(q, initNs=namespace_d))}
    
    
    uri_replacements ={}
    for k,v in row_object_keys_d.items():
        print(k,v)
        target_keys = list(loader.search_on_key_value(staging_graph, namespace_d, "dm:UniqueIdentifier", k))
        row_keys = list(loader.search_on_key_value(row_graph, namespace_d, "dm:UniqueIdentifier", k))

        if len(target_keys)>0 and len(row_keys)>0:
            uri_replacements [row_keys[0][0]]=target_keys[0][0]
        else:
            uri_replacements [row_keys[0][0]]=row_keys[0][0]

    # Extract all the raw triples from row_graph
    # Pass them through the replacements dictionary and 
    # Load the converted ones into the staging_graph...
    stage_triples = []
    for s,p,o in row_graph_triples + unique_id_triples:
        stage_triples.append((uri_replacements.get(s,s), p, uri_replacements.get(o,o)))


    for t in stage_triples:
        staging_graph.add(t)
# Out:
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute PersonID
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Person
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Person')), (rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions')), (rdflib.term.Literal('Person'), rdflib.term.Literal('PersonID'))]
# core.principal_interactions.person http://temp/ac48f71100bb4953bd2ccf1641121adc
# core.principal_interactions http://temp/0a93f6e460b441db9e944d324dd07ab8
# core http://temp/dadd0ede2ac54a789727f4c30e2ed0a1
# core.principal_interactions.person.personid http://temp/ecad1f5c39f442069c392c9f0fde1f01
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute FirstName
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Person
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Person')), (rdflib.term.Literal('Person'), rdflib.term.Literal('FirstName')), (rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions'))]
# core http://temp/3405174df5ba49cea014cf1644270603
# core.principal_interactions.person.firstname http://temp/02b32a82933440bf96ac095088bbfe5c
# core.principal_interactions.person http://temp/8b2864b4a29146f497cadb00320d787b
# core.principal_interactions http://temp/fdbedaa42d8d49ee8d2eb4479cb665a0
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute FamilyName
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Person
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Person')), (rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions')), (rdflib.term.Literal('Person'), rdflib.term.Literal('FamilyName'))]
# core.principal_interactions.person http://temp/d2bac8db9c57464aab7dbe913d0b6a65
# core.principal_interactions http://temp/6962170a556e4eaa9372adedfed13a2e
# core.principal_interactions.person.familyname http://temp/8ff1c9d846e5414fae08ea8c4ba7ef10
# core http://temp/2befe1843dbd49208e99bde81486960c
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute DateOfBirth
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Person
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Person'), rdflib.term.Literal('DateOfBirth')), (rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Person')), (rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions'))]
# core http://temp/0d210b8ec78e4e8eb2fbebfbb8f43e5d
# core.principal_interactions.person http://temp/e605832ec37d45cb8b4655174fe9d5bf
# core.principal_interactions http://temp/0496fabc14254c97a35b4881ed5fa1c7
# core.principal_interactions.person.dateofbirth http://temp/56a37536cca844f1a4e73f9785adb910
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute DateOfDeath
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Person
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions')), (rdflib.term.Literal('Person'), rdflib.term.Literal('DateOfDeath')), (rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Person'))]
# core.principal_interactions.person http://temp/5e979c463a594cf5b864aee056277025
# core http://temp/64e3f304d42242b5962df334ea7a7e31
# core.principal_interactions.person.dateofdeath http://temp/1e6b7ca0715746f4990a5e2c510f8fbe
# core.principal_interactions http://temp/be6728cb91374e3e84e7d3fcf2b787ee
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute Address Line 1
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Address
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Address'), rdflib.term.Literal('Address Line 1')), (rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions')), (rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Address'))]
# core.principal_interactions.address http://temp/7b49a5994ee3430caeb01828cc41815d
# core.principal_interactions http://temp/3944b0b75aad4b789d61547b72903601
# core.principal_interactions.address.address_line_1 http://temp/6e543036f12d423193b8859bba128080
# core http://temp/ec8f6755498941f982577a9fd6a76649
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute Address Line 2
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Address
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Address'), rdflib.term.Literal('Address Line 2')), (rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions')), (rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Address'))]
# core http://temp/fb94c484fb394cb7b3c213bf8fe8f088
# core.principal_interactions http://temp/31b189c8a8fe4e0c876e61c4b02598b6
# core.principal_interactions.address http://temp/47ddc0a0ebd4402d8c9c69b492da3054
# core.principal_interactions.address.address_line_2 http://temp/642c5c172a034a6499a042dd4e74739e
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute Address Line 3
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Address
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions')), (rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Address')), (rdflib.term.Literal('Address'), rdflib.term.Literal('Address Line 3'))]
# core.principal_interactions.address.address_line_3 http://temp/918094e3b9684a1ebaeb2f7549d4071e
# core.principal_interactions http://temp/d71fccebd1c9452abf8efb2f62c34774
# core http://temp/8baac0500488434d925cdb2ae6471690
# core.principal_interactions.address http://temp/91c636ae3d594f40a6dc1e70a12da1dd
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute Postal Code
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Address
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Address'), rdflib.term.Literal('Postal Code')), (rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Address')), (rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions'))]
# core.principal_interactions http://temp/1b822136518742149dd18116bb9888e7
# core.principal_interactions.address.postal_code http://temp/dcc31797770e4151a149eaa40aa1557b
# core http://temp/15e47271cddd4e0e865107d83d92ef46
# core.principal_interactions.address http://temp/0ad04b8c706c4733b38ec60c8ba71f4a
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute Country
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Address
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Address'), rdflib.term.Literal('Country')), (rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions')), (rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Address'))]
# core.principal_interactions http://temp/b24ce3d86ae7496bb6e6e8cea78f51bd
# core.principal_interactions.address http://temp/12ac594c6bc749e6b7fae1fd1653334a
# core.principal_interactions.address.country http://temp/3d0127cec9a049dd9e57733820130b0f
# core http://temp/e7c3b2fdf3b84110a4b4c7b7b743643b
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute Country
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Address
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Address'), rdflib.term.Literal('Country')), (rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Address')), (rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions'))]
# core.principal_interactions.address.country http://temp/ef1afe22b2fc4bec8b18e712b6e7df01
# core http://temp/5e2e0dbc20a14e8b814a5c8878336fd1
# core.principal_interactions.address http://temp/a7c207ca28c748d397e58548a32e5f80
# core.principal_interactions http://temp/6f97d3e17e574a9aaa84148cdb906a1a
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute Coverage Type
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Insurance Product
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions')), (rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Insurance Product')), (rdflib.term.Literal('Insurance Product'), rdflib.term.Literal('Coverage Type'))]
# core.principal_interactions.insurance_product http://temp/0e91e84c1e854fd6bd85083cb97a9292
# core http://temp/f763d52ea033423b8e63f911f1e94d0f
# core.principal_interactions.insurance_product.coverage_type http://temp/cdc394f8465e4deaab919fc1ff9e676b
# core.principal_interactions http://temp/ffa22521eebc4423a754417edb843093
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute Policy ID
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Insurance Policy
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Insurance Policy')), (rdflib.term.Literal('Insurance Policy'), rdflib.term.Literal('Policy ID')), (rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions'))]
# core http://temp/90fc87e5418e486f85d865e149ed4262
# core.principal_interactions.insurance_policy http://temp/559be03fca34497aa539ddc43029959a
# core.principal_interactions.insurance_policy.policy_id http://temp/ca04c7a9c1974f09b1b0050898912efd
# core.principal_interactions http://temp/cf096f480b07411fb5d31a923fa800d0
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute Start Date
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Insurance Policy
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Insurance Policy'), rdflib.term.Literal('Start Date')), (rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Insurance Policy')), (rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions'))]
# core.principal_interactions.insurance_policy http://temp/546f1519799b438eba0cc5d042c7ab96
# core.principal_interactions http://temp/ce0da3b5bf054399a9cc496c29e108aa
# core http://temp/7de367328dc24793bbe650edbc4c476a
# core.principal_interactions.insurance_policy.start_date http://temp/315eea43a8d945fa95908c8483773f3b
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Attribute End Date
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Insurance Policy
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.DataModel Principal Interactions
# [(rdflib.term.Literal('Principal Interactions'), rdflib.term.Literal('Insurance Policy')), (rdflib.term.Literal('Core'), rdflib.term.Literal('Principal Interactions')), (rdflib.term.Literal('Insurance Policy'), rdflib.term.Literal('End Date'))]
# core.principal_interactions.insurance_policy http://temp/e8977d32b0724c5ebe8c0bc73ba0d218
# core.principal_interactions http://temp/e0128230dbf44a57888e4639835c5f60
# core http://temp/50ea2498cf6745e78c35d876d077c82e
# core.principal_interactions.insurance_policy.end_date http://temp/0b21e91f72324f41bb5c0a308c6a76ec

# %%
visualize(staging_graph)

# %%
# Now load up some relationships

data_rows = [{ "Business Domain" : "Core", 
             "Model" : "Principal Interactions", 
             "ModelType" : "Conceptual", 
             "Relationship" : "PersonHasPolicy", 
             "FromClass" : "Person", 
             "ToClass" : "Insurance Policy"}]

# %%
q="""SELECT distinct ?s ?o
WHERE

{
    {?s ?p ?o .
     # ?h rdfs:subPropertyOf dm:HierarchicalRelations.
     BIND (dm:UniqueIdentifier as ?p)
     # ?s dm:UniqueIdentifier ?o .
     FILTER NOT EXISTS {?s rdf:type dm:RowNode . }
     }
     
}
 
 """

serialization_name = "RelationshipRecord"

for e,r in enumerate(data_rows):
    m_data = mapping_data[serialization_name]
    row_graph_triples = loader.gen_temp_entity_triples_from_row(m_data, mappable_things_ext, "http://temp", r, row_id=f'row_{e}')
    row_graph=Graph()
    for t in row_graph_triples:
        row_graph.add(t)
    # connect additional context to row-graph
    row_graph.parse ("datamodels_rdf.owl", format='xml')
    dmns = Namespace(onto.base_iri)
    row_graph.bind('dm', dmns)
    row_graph.bind('rdfs', RDFS)
    namespace_d = {'dm': dmns, 'rdfs' : RDFS, 'rdf' : RDF}
    unique_id_triples=loader.gen_unique_identity_triples(row_graph, namespace_d)
    for t in unique_id_triples:
        row_graph.add(t)
        
    #{dir(k):v for k,v in list(row_graph.query(q, initNs={'dm': dmns, 'rdfs' : RDFS, 'rdf' : RDF}))}

    row_object_keys_d = {v.value:k.n3()[1:-1] for k,v in list(row_graph.query(q, initNs=namespace_d))}
    
    
    uri_replacements ={}
    for k,v in row_object_keys_d.items():
        print(k,v)
        target_keys = list(loader.search_on_key_value(staging_graph, namespace_d, "dm:UniqueIdentifier", k))
        row_keys = list(loader.search_on_key_value(row_graph, namespace_d, "dm:UniqueIdentifier", k))

        if len(target_keys)>0 and len(row_keys)>0:
            uri_replacements [row_keys[0][0]]=target_keys[0][0]
        else:
            uri_replacements [row_keys[0][0]]=row_keys[0][0]

    # Extract all the raw triples from row_graph
    # Pass them through the replacements dictionary and 
    # Load the converted ones into the staging_graph...
    stage_triples = []
    for s,p,o in row_graph_triples + unique_id_triples:
        stage_triples.append((uri_replacements.get(s,s), p, uri_replacements.get(o,o)))


    for t in stage_triples:
        staging_graph.add(t)
# Out:
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'IOMemory']]. datamodels_rdf.Class Person
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-7d2c09e4d133> in <module>
#      18 for e,r in enumerate(data_rows):
#      19     m_data = mapping_data[serialization_name]
# ---> 20     row_graph_triples = loader.gen_temp_entity_triples_from_row(m_data, mappable_things_ext, "http://temp", r, row_id=f'row_{e}')
#      21     row_graph=Graph()
#      22     for t in row_graph_triples:
#
# ~/Documents/Coding/gitHub/datamodels/loader.py in gen_temp_entity_triples_from_row(s_mappings, onto_map, namespace, row, row_id)
#      77                 if prop_type == "class":
#      78                     print(row_g, prop_range, data)
# ---> 79                     obj_node = get_thing_from_label_graphsearch(row_g, prop_range, search_key=data)[0]
#      80                 elif prop_type == "data" :
#      81                     obj_node = Literal(data)
#
# IndexError: list index out of range
