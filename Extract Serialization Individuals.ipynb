# %%
import rdflib
from rdflib import URIRef, Literal, Graph

import loader
import discourse
import pandas as pd
from rdflib import Graph, Namespace
from rdflib.namespace import RDF, RDFS
import io
import pydotplus
from IPython.display import display, Image
from rdflib.tools.rdf2dot import rdf2dot
from IPython.core.display import HTML

import owlready2 as owlr


def visualize(g):
    stream = io.StringIO()
    rdf2dot(g, stream, opts = {display})
    dg = pydotplus.graph_from_dot_data(stream.getvalue())
    png = dg.create_png()

    display(Image(png))

def t2rdflibg(triples): #triples to rdflib graph
    g = Graph()
    for t in triples:
        g.add(t)
    return g


def nan2None(value):
    if pd.isnull(value) :
        return None
    else:
        return value


def get_data_rows(filename):
    data_rows_df = pd.read_csv(filename)
    data_rows=[]
    for i,r in data_rows_df.iterrows():
        r_d = {k:nan2None(v) for k,v in dict(r).items()}

        data_rows.append(r_d)
    del data_rows_df
    return data_rows

serial_key = { "Business Domain" : "ModelDomain", 
               "Model" : "Model", 
               "ModelType" : "ModelType", 
               "Entity" : "Class", 
               "Attribute" : "Attribute", 
               "DataType" : "DataType", 
               "Context" : "Context", 
               "SubContext" : "SubContext", 
               "Relationship" : "Relationship", 
               "Entity From" : "FromClass",
               "Attribute From" : "FromAttribute", 
               "Cardinality From" : "FromCardinality",
               "Entity To" : "ToClass",
               "Attribute To" : "ToAttribute",
               "Cardinality To" : "ToCardinality"
}

onto = owlr.get_ontology("datamodels_rdf.owl").load()
ser_onto = owlr.get_ontology("Serialization.owl").load()
def flush(onto):
    for m in onto.Serialization.instances()[0].Contains:
        print(m, m.is_a)
flush(onto)
owlr.sync_reasoner(onto)
# Out:
# datamodels_rdf.Mapping_Attribute [datamodels_rdf.EntityMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_AttributeHasDataType [datamodels_rdf.DataPropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_Class [datamodels_rdf.EntityMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_ClassContainsAttribute [datamodels_rdf.PropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_Context [datamodels_rdf.EntityMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_ContextContainsClass [datamodels_rdf.PropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_ContextContainsSubContext [datamodels_rdf.PropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_DomainContainsModel [datamodels_rdf.PropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_FromAttribute [datamodels_rdf.EntityMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_FromClass [datamodels_rdf.EntityMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_Model [datamodels_rdf.EntityMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_ModelContainsClass [datamodels_rdf.PropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_ModelContainsContext [datamodels_rdf.PropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_ModelContainsRelationship [datamodels_rdf.PropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_ModelDomain [datamodels_rdf.EntityMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_ModelHasModelType [datamodels_rdf.DataPropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_Relationship [datamodels_rdf.EntityMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_RelationshipFromAttribute [datamodels_rdf.PropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_RelationshipFromCardinality [datamodels_rdf.DataPropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_RelationshipFromClass [datamodels_rdf.PropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_RelationshipToAttribute [datamodels_rdf.PropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_RelationshipToCardinality [datamodels_rdf.DataPropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_RelationshipToClass [datamodels_rdf.PropertyMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_SubContext [datamodels_rdf.EntityMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_ToAttribute [datamodels_rdf.EntityMapping, Serialization.Mapping]
# datamodels_rdf.Mapping_ToClass [datamodels_rdf.EntityMapping, Serialization.Mapping]
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /usr/local/python/py36/lib/python3.6/site-packages/owlready2/hermit:/usr/local/python/py36/lib/python3.6/site-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////var/folders/rd/q3bhk6_n56x75m05pp2sq7dr0000gn/T/tmpsrm0ydm1
# * Owlready2 * HermiT took 0.7223808765411377 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
for i in onto.individuals():
    print("thing", i.iri)
#    print(dir(i))
#    for ip in i.get_properties():
#        try:
#            print("\t", ip.iri, getattr(i, ip.python_name))
#        except:
#            print("\t", ip.iri, "?")
#            pass
# Out:
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Model
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelDomain
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Relationship
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromAttribute
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromClass
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToAttribute
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToClass
# thing http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipRecord

# %%
onto.search(is_a=onto.MetaClass)
# Out:
# [datamodels_rdf.MetaClass, datamodels_rdf.Attribute, datamodels_rdf.Model, datamodels_rdf.Class, datamodels_rdf.Context, datamodels_rdf.ModelDomain, datamodels_rdf.Relationship, datamodels_rdf.CompoundAttribute, datamodels_rdf.FunctionalIdentifier, datamodels_rdf.FunctionalPartialIdentifier, datamodels_rdf.ConceptualDataModel, datamodels_rdf.LogicalDataModel, datamodels_rdf.MasterDataModel, datamodels_rdf.PhysicalDataModel, datamodels_rdf.AbstractClass, datamodels_rdf.ConceptClass, datamodels_rdf.LogicalEntityClass, datamodels_rdf.PhysicalEntityClass]

# %%
onto.search(is_a=onto.MetaProperty)
# Out:
# [datamodels_rdf.MetaProperty, datamodels_rdf.Contains, datamodels_rdf.MemberOf, datamodels_rdf.RelationshipFromAttribute, datamodels_rdf.RelationshipFromClass, datamodels_rdf.RelationshipToAttribute, datamodels_rdf.RelationshipToClass]

# %%
onto.search(is_a=onto.MetaDataProperty)
# Out:
# [datamodels_rdf.MetaDataProperty, datamodels_rdf.Cardinality, datamodels_rdf.DataType, datamodels_rdf.FromCardinality, datamodels_rdf.ModelType, datamodels_rdf.Optionality, datamodels_rdf.ToCardinality]

# %%
# These are all the pointers to meta contents authored in specific ontologies elsewhere
meta_contents = []
for m in sorted(onto.MetaClass.instances(), key=lambda x:x.name):
    print(m)
    t = (URIRef(m.iri), URIRef(RDF.type), URIRef(ser_onto.MetaClass.iri))
    meta_contents.append(t)
    
for m in sorted(onto.MetaProperty.instances(), key=lambda x:x.name):
    print(m)
    t = (URIRef(m.iri), URIRef(RDF.type), URIRef(ser_onto.MetaProperty.iri))
    meta_contents.append(t)
    
for m in sorted(onto.MetaDataProperty.instances(), key=lambda x:x.name):
    print(m)
    t = (URIRef(m.iri), URIRef(RDF.type), URIRef(ser_onto.MetaDataProperty.iri))
    meta_contents.append(t)
# Out:
# datamodels_rdf.Attribute
# datamodels_rdf.Attribute
# datamodels_rdf.Class
# datamodels_rdf.Class
# datamodels_rdf.Context
# datamodels_rdf.Context
# datamodels_rdf.Model
# datamodels_rdf.Model
# datamodels_rdf.ModelDomain
# datamodels_rdf.ModelDomain
# datamodels_rdf.Relationship
# datamodels_rdf.Relationship
# datamodels_rdf.Contains
# datamodels_rdf.Contains
# datamodels_rdf.MemberOf
# datamodels_rdf.MemberOf
# datamodels_rdf.RelationshipFromAttribute
# datamodels_rdf.RelationshipFromAttribute
# datamodels_rdf.RelationshipFromClass
# datamodels_rdf.RelationshipFromClass
# datamodels_rdf.RelationshipToAttribute
# datamodels_rdf.RelationshipToAttribute
# datamodels_rdf.RelationshipToClass
# datamodels_rdf.RelationshipToClass
# datamodels_rdf.Cardinality
# datamodels_rdf.Cardinality
# datamodels_rdf.DataType
# datamodels_rdf.DataType
# datamodels_rdf.FromCardinality
# datamodels_rdf.FromCardinality
# datamodels_rdf.ModelType
# datamodels_rdf.ModelType
# datamodels_rdf.Optionality
# datamodels_rdf.Optionality
# datamodels_rdf.ToCardinality
# datamodels_rdf.ToCardinality

# %%
# Mappings belong to the serialization ontology (so types should be updated accordingly)
mappings = []
for m in onto.Mapping.instances():
    print(m)
    t = (URIRef(m.iri), URIRef(RDF.type), URIRef(ser_onto.Mapping.iri))
    mappings.append(t)
    for p in m.get_properties():
        if p == onto.MappingMetaTarget:
            mt = p[m].first().iri
            if URIRef(mt) not in [c[0] for c in meta_contents]:
                print(mt, "not in meta_contents")
            t=(URIRef(m.iri), URIRef(ser_onto.MappingMetaTarget.iri), URIRef(mt))
        elif p in (onto.SerializationParentLabel, onto.SerializationLabel, onto.MappingDomain, onto.MappingRange):
            pl=p[m].first()
            t=(URIRef(m.iri), URIRef(p.iri.replace(onto.base_iri,ser_onto.base_iri)), Literal(pl))
        else:
            print("\t", p, "other")
            t=None
        
        if t is not None:
        
            mappings.append(t)
mappings
# Out:
# datamodels_rdf.Mapping_Attribute
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_AttributeHasDataType
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_Class
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_ClassContainsAttribute
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_Context
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_ContextContainsClass
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_ContextContainsSubContext
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_DomainContainsModel
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_FromAttribute
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_FromClass
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_Model
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_ModelContainsClass
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_ModelContainsContext
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_ModelContainsRelationship
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_ModelDomain
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_ModelHasModelType
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_Relationship
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_RelationshipFromAttribute
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_RelationshipFromCardinality
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_RelationshipFromClass
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_RelationshipToAttribute
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_RelationshipToCardinality
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_RelationshipToClass
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_SubContext
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_ToAttribute
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_ToClass
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_AttributeHasDataType
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_ModelHasModelType
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_RelationshipFromCardinality
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_RelationshipToCardinality
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_Attribute
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_Class
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_Context
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_FromAttribute
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_FromClass
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_Model
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_ModelDomain
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_Relationship
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_SubContext
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_ToAttribute
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_ToClass
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.SerializationParentLabel other
# 	 Serialization.SerializationLabel other
# datamodels_rdf.Mapping_ClassContainsAttribute
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_ContextContainsClass
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_ContextContainsSubContext
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_DomainContainsModel
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_ModelContainsClass
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_ModelContainsContext
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_ModelContainsRelationship
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_RelationshipFromAttribute
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_RelationshipFromClass
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_RelationshipToAttribute
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# datamodels_rdf.Mapping_RelationshipToClass
# 	 datamodels_rdf.MemberOf other
# 	 Serialization.MappingRange other
# 	 Serialization.MappingMetaTarget other
# 	 Serialization.MappingMemberOf other
# 	 Serialization.MappingDomain other
# [(rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('DataType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#DataType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('SubContext')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('ModelDomain')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('FromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('FromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('FromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Model'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Model'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Model'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('ModelDomain')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Model'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelDomain'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelDomain'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ModelDomain')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelDomain'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('ModelDomain')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ModelType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ModelType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Relationship'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Relationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Relationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Relationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('FromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('FromCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#FromCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('FromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ToCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ToCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('SubContext')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('ToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('ToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('ToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('DataType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#DataType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ModelType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ModelType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('FromCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#FromCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ToCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ToCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
# ...
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Relationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('SubContext')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('ToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('ToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('ToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('SubContext')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('ModelDomain')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('FromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('FromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToClass'))]

# %%
serializations = []
for s in onto.Serialization.instances():
    print(s)
    t = (URIRef(s.iri), URIRef(RDF.type), URIRef(ser_onto.Serialization.iri))
    serializations.append(t)
    try:
        for p in s.Contains:
            print(p)
            #if URIRef(p.iri.replace(onto.base_iri,ser_onto.base_iri)) not in [m[0] for m in mappings]:
            if URIRef(p.iri) not in [m[0] for m in mappings]:
                
                print ("no mapping!")
                print(p.iri, p.iri.replace(onto.base_iri,ser_onto.base_iri))
                
                print()
            t = (URIRef(s.iri), URIRef(ser_onto.ContainsMapping.iri), URIRef(p.iri))
            serializations.append(t)
    except AttributeError:
        print(s, "has no Contains")
        pass
        #assert False
# Out:
# datamodels_rdf.EntityAttributeRecord
# datamodels_rdf.Mapping_Attribute
# datamodels_rdf.Mapping_AttributeHasDataType
# datamodels_rdf.Mapping_Class
# datamodels_rdf.Mapping_ClassContainsAttribute
# datamodels_rdf.Mapping_Context
# datamodels_rdf.Mapping_ContextContainsClass
# datamodels_rdf.Mapping_ContextContainsSubContext
# datamodels_rdf.Mapping_DomainContainsModel
# datamodels_rdf.Mapping_FromAttribute
# datamodels_rdf.Mapping_FromClass
# datamodels_rdf.Mapping_Model
# datamodels_rdf.Mapping_ModelContainsClass
# datamodels_rdf.Mapping_ModelContainsContext
# datamodels_rdf.Mapping_ModelContainsRelationship
# datamodels_rdf.Mapping_ModelDomain
# datamodels_rdf.Mapping_ModelHasModelType
# datamodels_rdf.Mapping_Relationship
# datamodels_rdf.Mapping_RelationshipFromAttribute
# datamodels_rdf.Mapping_RelationshipFromCardinality
# datamodels_rdf.Mapping_RelationshipFromClass
# datamodels_rdf.Mapping_RelationshipToAttribute
# datamodels_rdf.Mapping_RelationshipToCardinality
# datamodels_rdf.Mapping_RelationshipToClass
# datamodels_rdf.Mapping_SubContext
# datamodels_rdf.Mapping_ToAttribute
# datamodels_rdf.Mapping_ToClass
# datamodels_rdf.RelationshipRecord
# datamodels_rdf.RelationshipRecord has no Contains

# %%
serializations
# Out:
# [(rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Serialization')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelDomain')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipRecord'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Serialization'))]

# %%
graph_contents = meta_contents + mappings + serializations

# %%
g = rdflib.Graph()
for t in graph_contents:
    g.add(t)

# %%
visualize(g)

# %%
g.serialize(format="xml", destination="EntityAttributeRecord.rdf")

# %%
graph_contents
# Out:
# [(rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Attribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Attribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Class'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Class'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Context'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Context'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Model'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Model'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ModelDomain'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ModelDomain'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Relationship'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Relationship'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#MemberOf'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#MemberOf'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Cardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaDataProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Cardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaDataProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#DataType'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaDataProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#DataType'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaDataProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#FromCardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaDataProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#FromCardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaDataProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ModelType'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaDataProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ModelType'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaDataProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Optionality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaDataProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Optionality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaDataProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ToCardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaDataProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ToCardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MetaDataProperty')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('DataType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#DataType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('SubContext')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('ModelDomain')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('FromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('FromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('FromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Model'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Model'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Model'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('ModelDomain')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Model'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelDomain'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelDomain'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ModelDomain')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelDomain'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('ModelDomain')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ModelType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ModelType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Relationship'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Relationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Relationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Relationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('FromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('FromCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#FromCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('FromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ToCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ToCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('SubContext')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('ToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('ToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('ToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('DataType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#DataType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ModelType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ModelType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('FromCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#FromCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ToCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#ToCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationParentLabel'),
#   rdflib.term.Literal('FromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#SerializationLabel'),
#   rdflib.term.Literal('FromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass'),
# ...
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Contains')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('FromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('FromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipFromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Mapping')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingRange'),
#   rdflib.term.Literal('ToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingDomain'),
#   rdflib.term.Literal('Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#MappingMetaTarget'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Serialization')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Attribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_AttributeHasDataType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Class')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ClassContainsAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Context')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ContextContainsSubContext')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_DomainContainsModel')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_FromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Model')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsContext')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelContainsRelationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelDomain')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ModelHasModelType')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_Relationship')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipFromClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToCardinality')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_RelationshipToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_SubContext')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToAttribute')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#EntityAttributeRecord'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#ContainsMapping'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#Mapping_ToClass')),
#  (rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#RelationshipRecord'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.semanticweb.org/tomk/ontologies/2022/11/serialization#Serialization'))]

# %%
onto
# Out:
# get_ontology("http://www.semanticweb.org/tomk/ontologies/2022/9/datamodel#")

# %%
onto.imported_ontologies
# Out:
# []

# %%
# Out:
# []

# %%
#ser_onto = owlr.get_ontology("Serialization.owl").load()
rdf_onto = owlr.get_ontology("EntityAttributeRecord.rdf").load()

# %%
ser_onto = owlr.get_ontology("Serialization.owl").load()
len(list(ser_onto.world.sparql("""SELECT ?S ?P ?O WHERE { ?S ?P ?O}""")))
# Out:
# 822

# %%
ser_onto = owlr.get_ontology("Serialization.owl").load()
ser_onto.imported_ontologies.append(rdf_onto)

# %%
list(ser_onto.world.sparql("""SELECT ?S ?P ?O WHERE { ?S ?P ?O}"""))
# Out:
# [[.anonymous, 6, owl.Ontology],
#  [11.discourse, 6, owl.Ontology],
#  [discourse.Asserts, 6, owl.ObjectProperty],
#  [discourse.Asserts, 10, discourse.Posits],
#  [discourse.Asserts, 6, owl.AsymmetricProperty],
#  [discourse.Asserts, 6, owl.IrreflexiveProperty],
#  [discourse.Asserts, 7, discourse.Declaration],
#  [discourse.Asserts, 8, discourse.Posit],
#  [discourse.Asserts, 89, discourse.Refutes],
#  [discourse.Atom, 6, owl.ObjectProperty],
#  [discourse.Atom, 7, discourse.Posit],
#  [discourse.DiscourseContains, 6, owl.ObjectProperty],
#  [discourse.DiscourseContains, 6, owl.TransitiveProperty],
#  [discourse.DiscourseContains, 7, discourse.Discourse],
#  [discourse.DiscourseContains, 8, discourse.Declaration],
#  [discourse.DiscourseContains, 8, discourse.Discourse],
#  [discourse.Object, 6, owl.ObjectProperty],
#  [discourse.Object, 10, discourse.Atom],
#  [discourse.Object, 7, discourse.Posit],
#  [discourse.Posits, 6, owl.ObjectProperty],
#  [discourse.Posits, 6, owl.AsymmetricProperty],
#  [discourse.Posits, 6, owl.IrreflexiveProperty],
#  [discourse.Posits, 7, discourse.Declaration],
#  [discourse.Posits, 8, discourse.Posit],
#  [discourse.Predicate, 6, owl.ObjectProperty],
#  [discourse.Predicate, 10, discourse.Atom],
#  [discourse.Predicate, 7, discourse.Posit],
#  [discourse.Proposes, 6, owl.ObjectProperty],
#  [discourse.Proposes, 16, discourse.isProposedBy],
#  [discourse.Proposes, 8, discourse.Declaration],
#  [discourse.Proposes, 8, discourse.Discourse],
#  [discourse.Refutes, 6, owl.ObjectProperty],
#  [discourse.Refutes, 10, discourse.Posits],
#  [discourse.Refutes, 6, owl.AsymmetricProperty],
#  [discourse.Refutes, 6, owl.IrreflexiveProperty],
#  [discourse.Refutes, 7, discourse.Declaration],
#  [discourse.Refutes, 8, discourse.Posit],
#  [discourse.Subject, 6, owl.ObjectProperty],
#  [discourse.Subject, 10, discourse.Atom],
#  [discourse.Subject, 7, discourse.Posit],
#  [discourse.isProposedBy, 6, owl.ObjectProperty],
#  [discourse.isProposedBy, 7, discourse.Declaration],
#  [discourse.isProposedBy, 7, discourse.Discourse],
#  [discourse.Digest, 6, owl.DatatypeProperty],
#  [discourse.Digest, 7, discourse.Posit],
#  [discourse.Digest, 8, str],
#  [discourse.GeneratedOn, 6, owl.DatatypeProperty],
#  [discourse.GeneratedOn, 8, datetime.datetime],
#  [discourse.Assertion, 6, 11],
#  [Inverse(discourse.Asserts).some(discourse.Declaration), 6, 17],
#  [Inverse(discourse.Asserts), 16, discourse.Asserts],
#  [Inverse(discourse.Asserts).some(discourse.Declaration),
#   18,
#   Inverse(discourse.Asserts)],
#  [Inverse(discourse.Asserts).some(discourse.Declaration),
#   24,
#   discourse.Declaration],
#  [discourse.Assertion,
#   33,
#   Inverse(discourse.Asserts).some(discourse.Declaration)],
#  [discourse.Assertion, 9, discourse.Posit],
#  [discourse.Declaration, 6, 11],
#  [discourse.Discourse, 6, 11],
#  [discourse.Interlocutor, 6, 11],
#  [discourse.Posit, 6, 11],
#  [discourse.Refutation, 6, 11],
#  [Inverse(discourse.Refutes).some(discourse.Declaration), 6, 17],
#  [Inverse(discourse.Refutes), 16, discourse.Refutes],
#  [Inverse(discourse.Refutes).some(discourse.Declaration),
#   18,
#   Inverse(discourse.Refutes)],
#  [Inverse(discourse.Refutes).some(discourse.Declaration),
#   24,
#   discourse.Declaration],
#  [discourse.Refutation,
#   33,
#   Inverse(discourse.Refutes).some(discourse.Declaration)],
#  [discourse.Refutation, 9, discourse.Posit],
#  [9.datamodel, 6, owl.Ontology],
#  [core.definition, 6, owl.AnnotationProperty],
#  [core.example, 6, owl.AnnotationProperty],
#  [datamodels_rdf.ClassToClassRelationship, 6, owl.ObjectProperty],
#  [datamodels_rdf.ClassToClassRelationship, 10, owl.topObjectProperty],
#  [datamodels_rdf.Contains, 6, owl.ObjectProperty],
#  [datamodels_rdf.Contains, 16, datamodels_rdf.MemberOf],
#  [datamodels_rdf.Contains, 6, owl.AsymmetricProperty],
#  [datamodels_rdf.Contains, 6, owl.IrreflexiveProperty],
#  [datamodels_rdf.MappingMetaTarget, 6, owl.ObjectProperty],
#  [datamodels_rdf.MappingMetaTarget, 7, datamodels_rdf.Mapping],
#  [datamodels_rdf.MappingMetaTarget, 8, datamodels_rdf.Meta],
#  [datamodels_rdf.MemberOf, 6, owl.ObjectProperty],
#  [datamodels_rdf.MemberOf, 6, owl.AsymmetricProperty],
#  [datamodels_rdf.MemberOf, 6, owl.IrreflexiveProperty],
#  [datamodels_rdf.Cardinality, 6, owl.DatatypeProperty],
#  [OneOf(['Many', 'One']), 6, 90],
#  [_:6, 6, 22-rdf-syntax-ns.List],
#  [_:7, 6, 22-rdf-syntax-ns.List],
#  [_:7, 4, 5],
#  [_:6, 4, _:7],
#  [OneOf(['Many', 'One']), 32, _:6],
#  [datamodels_rdf.Cardinality, 8, OneOf(['Many', 'One'])],
#  [datamodels_rdf.DataType, 6, owl.DatatypeProperty],
#  [datamodels_rdf.DataType, 7, datamodels_rdf.Attribute],
#  [datamodels_rdf.DataType, 8, str],
#  [datamodels_rdf.Description, 6, owl.DatatypeProperty],
#  [datamodels_rdf.Description, 7, datamodels_rdf.Definition],
#  [datamodels_rdf.Description, 8, str],
#  [datamodels_rdf.FromCardinality, 6, owl.DatatypeProperty],
#  [datamodels_rdf.FromCardinality, 10, datamodels_rdf.Cardinality],
#  [datamodels_rdf.GeneratedOn, 6, owl.DatatypeProperty],
#  [datamodels_rdf.GeneratedOn, 6, owl.FunctionalProperty],
#  [datamodels_rdf.GeneratedOn, 7, datamodels_rdf.DataLoad],
#  [datamodels_rdf.GeneratedOn, 8, datetime.datetime],
#  [datamodels_rdf.MappingDomain, 6, owl.DatatypeProperty],
#  [datamodels_rdf.MappingDomain, 7, datamodels_rdf.Mapping],
#  [datamodels_rdf.MappingDomain, 8, str],
#  [datamodels_rdf.MappingLabel, 6, owl.DatatypeProperty],
#  [datamodels_rdf.MappingLabel, 7, datamodels_rdf.Mapping],
#  [datamodels_rdf.MappingLabel, 8, str],
#  [datamodels_rdf.MappingRange, 6, owl.DatatypeProperty],
#  [datamodels_rdf.MappingRange, 7, datamodels_rdf.Mapping],
#  [datamodels_rdf.MappingRange, 8, str],
#  [datamodels_rdf.MappingSubType, 6, owl.DatatypeProperty],
#  [datamodels_rdf.MappingSubType, 7, datamodels_rdf.Mapping],
#  [OneOf(['Entity', 'Property']), 6, 90],
#  [_:9, 6, 22-rdf-syntax-ns.List],
#  [_:10, 6, 22-rdf-syntax-ns.List],
#  [_:10, 4, 5],
#  [_:9, 4, _:10],
#  [OneOf(['Entity', 'Property']), 32, _:9],
#  [datamodels_rdf.MappingSubType, 8, OneOf(['Entity', 'Property'])],
#  [datamodels_rdf.ModelType, 6, owl.DatatypeProperty],
#  [datamodels_rdf.ModelType, 7, datamodels_rdf.Model],
#  [datamodels_rdf.ModelType, 8, str],
#  [datamodels_rdf.Name, 6, owl.DatatypeProperty],
#  [datamodels_rdf.Name, 7, datamodels_rdf.Definition],
#  [datamodels_rdf.Name, 8, str],
#  [datamodels_rdf.Optionality, 6, owl.DatatypeProperty],
#  [OneOf(['Mandatory', 'Optional']), 6, 90],
#  [_:12, 6, 22-rdf-syntax-ns.List],
#  [_:13, 6, 22-rdf-syntax-ns.List],
#  [_:13, 4, 5],
#  [_:12, 4, _:13],
#  [OneOf(['Mandatory', 'Optional']), 32, _:12],
#  [datamodels_rdf.Optionality, 8, OneOf(['Mandatory', 'Optional'])],
#  [datamodels_rdf.SerializationLabel, 6, owl.DatatypeProperty],
#  [datamodels_rdf.SerializationLabel, 7, datamodels_rdf.Mapping],
#  [datamodels_rdf.SerializationLabel, 8, str],
#  [datamodels_rdf.SerializationParentLabel, 6, owl.DatatypeProperty],
#  [datamodels_rdf.ToCardinality, 6, owl.DatatypeProperty],
#  [datamodels_rdf.ToCardinality, 10, datamodels_rdf.Cardinality],
#  [datamodels_rdf.UniqueIdentifier, 6, owl.DatatypeProperty],
#  [datamodels_rdf.UniqueIdentifier, 6, owl.FunctionalProperty],
#  [datamodels_rdf.UniqueIdentifier, 7, datamodels_rdf.Definition],
#  [datamodels_rdf.UniqueIdentifier, 8, str],
#  [datamodels_rdf.isIdentifierForClass, 6, owl.DatatypeProperty],
#  [datamodels_rdf.isIdentifierForClass, 7, datamodels_rdf.Attribute],
#  [datamodels_rdf.isIdentifierForClass, 8, bool],
#  [datamodels_rdf.isPartialIdentifierForClass, 6, owl.DatatypeProperty],
#  [datamodels_rdf.isPartialIdentifierForClass, 7, datamodels_rdf.Attribute],
#  [datamodels_rdf.isPartialIdentifierForClass, 8, bool],
#  [datamodels_rdf.AbstractClass, 6, 11],
#  [datamodels_rdf.AbstractClass, 9, datamodels_rdf.Class],
#  [datamodels_rdf.Attribute, 6, 11],
#  [datamodels_rdf.Attribute, 9, datamodels_rdf.Definition],
#  [datamodels_rdf.BatchDefinition, 6, 11],
#  [datamodels_rdf.BatchDefinition, 9, datamodels_rdf.SerializationSpecs],
#  [datamodels_rdf.BatchNode, 6, 11],
#  [datamodels_rdf.BatchNode, 9, datamodels_rdf.DataLoad],
#  [datamodels_rdf.Class, 6, 11],
#  [datamodels_rdf.Class, 9, datamodels_rdf.Definition],
#  [datamodels_rdf.CompoundAttribute, 6, 11],
#  [datamodels_rdf.Contains.some(datamodels_rdf.Attribute), 6, 17],
#  [datamodels_rdf.Contains.some(datamodels_rdf.Attribute),
#   18,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Contains.some(datamodels_rdf.Attribute),
#   24,
#   datamodels_rdf.Attribute],
#  [datamodels_rdf.CompoundAttribute,
#   33,
#   datamodels_rdf.Contains.some(datamodels_rdf.Attribute)],
#  [datamodels_rdf.CompoundAttribute, 9, datamodels_rdf.Attribute],
#  [datamodels_rdf.ConceptClass, 6, 11],
#  [datamodels_rdf.ConceptClass, 9, datamodels_rdf.Class],
#  [datamodels_rdf.ConceptualDataModel, 6, 11],
#  [datamodels_rdf.ConceptualDataModel, 9, datamodels_rdf.Model],
#  [datamodels_rdf.Context, 6, 11],
#  [datamodels_rdf.Context, 9, datamodels_rdf.Definition],
#  [datamodels_rdf.DataLoad, 6, 11],
#  [datamodels_rdf.DataLoad, 9, datamodels_rdf.SerializationMetaData],
#  [datamodels_rdf.DataPropertyMapping, 6, 11],
#  [datamodels_rdf.Mapping & datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaDataProperty),
#   6,
#   11],
#  [datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaDataProperty),
#   6,
#   17],
#  [datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaDataProperty),
#   18,
#   datamodels_rdf.MappingMetaTarget],
#  [datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaDataProperty),
#   24,
#   datamodels_rdf.MetaDataProperty],
#  [_:17, 3, datamodels_rdf.Mapping],
#  [_:17, 4, _:18],
#  [_:18,
#   3,
#   datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaDataProperty)],
#  [_:18, 4, 5],
#  [datamodels_rdf.Mapping & datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaDataProperty),
#   31,
#   _:17],
#  [datamodels_rdf.DataPropertyMapping,
#   33,
#   datamodels_rdf.Mapping & datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaDataProperty)],
#  [datamodels_rdf.DataPropertyMapping, 9, datamodels_rdf.Mapping],
#  [datamodels_rdf.Definition, 6, 11],
#  [datamodels_rdf.EntityMapping, 6, 11],
#  [datamodels_rdf.Mapping & datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaClass),
#   6,
#   11],
#  [datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaClass), 6, 17],
#  [datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaClass),
#   18,
#   datamodels_rdf.MappingMetaTarget],
#  [datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaClass),
#   24,
#   datamodels_rdf.MetaClass],
#  [_:21, 3, datamodels_rdf.Mapping],
#  [_:21, 4, _:22],
#  [_:22, 3, datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaClass)],
#  [_:22, 4, 5],
#  [datamodels_rdf.Mapping & datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaClass),
#   31,
#   _:21],
#  [datamodels_rdf.EntityMapping,
#   33,
#   datamodels_rdf.Mapping & datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaClass)],
#  [datamodels_rdf.EntityMapping, 9, datamodels_rdf.Mapping],
#  [datamodels_rdf.FunctionalIdentifier, 6, 11],
#  [datamodels_rdf.Attribute & datamodels_rdf.isIdentifierForClass.value(True),
#   6,
#   11],
#  [datamodels_rdf.isIdentifierForClass.value(True), 6, 17],
#  [datamodels_rdf.isIdentifierForClass.value(True),
#   18,
#   datamodels_rdf.isIdentifierForClass],
#  [_:25, 3, datamodels_rdf.Attribute],
#  [_:25, 4, _:26],
#  [_:26, 3, datamodels_rdf.isIdentifierForClass.value(True)],
#  [_:26, 4, 5],
#  [datamodels_rdf.Attribute & datamodels_rdf.isIdentifierForClass.value(True),
#   31,
#   _:25],
#  [datamodels_rdf.FunctionalIdentifier,
#   33,
#   datamodels_rdf.Attribute & datamodels_rdf.isIdentifierForClass.value(True)],
#  [datamodels_rdf.FunctionalIdentifier, 9, datamodels_rdf.Attribute],
#  [datamodels_rdf.FunctionalIdentifier,
#   88,
#   datamodels_rdf.FunctionalPartialIdentifier],
#  [datamodels_rdf.FunctionalPartialIdentifier, 6, 11],
#  [datamodels_rdf.Attribute & (datamodels_rdf.isPartialIdentifierForClass.some(<class 'int'>) | datamodels_rdf.isPartialIdentifierForClass.value(True)),
#   6,
#   11],
#  [datamodels_rdf.isPartialIdentifierForClass.some(<class 'int'>) | datamodels_rdf.isPartialIdentifierForClass.value(True),
#   6,
#   11],
#  [datamodels_rdf.isPartialIdentifierForClass.some(<class 'int'>), 6, 17],
#  [datamodels_rdf.isPartialIdentifierForClass.some(<class 'int'>),
#   18,
#   datamodels_rdf.isPartialIdentifierForClass],
#  [datamodels_rdf.isPartialIdentifierForClass.some(<class 'int'>), 24, int],
#  [datamodels_rdf.isPartialIdentifierForClass.value(True), 6, 17],
#  [datamodels_rdf.isPartialIdentifierForClass.value(True),
#   18,
#   datamodels_rdf.isPartialIdentifierForClass],
#  [_:31, 3, datamodels_rdf.isPartialIdentifierForClass.some(<class 'int'>)],
#  [_:31, 4, _:32],
#  [_:32, 3, datamodels_rdf.isPartialIdentifierForClass.value(True)],
#  [_:32, 4, 5],
#  [datamodels_rdf.isPartialIdentifierForClass.some(<class 'int'>) | datamodels_rdf.isPartialIdentifierForClass.value(True),
#   30,
#   _:31],
#  [_:33, 3, datamodels_rdf.Attribute],
#  [_:33, 4, _:34],
#  [_:34,
#   3,
#   datamodels_rdf.isPartialIdentifierForClass.some(<class 'int'>) | datamodels_rdf.isPartialIdentifierForClass.value(True)],
#  [_:34, 4, 5],
#  [datamodels_rdf.Attribute & (datamodels_rdf.isPartialIdentifierForClass.some(<class 'int'>) | datamodels_rdf.isPartialIdentifierForClass.value(True)),
#   31,
#   _:33],
#  [datamodels_rdf.FunctionalPartialIdentifier,
#   33,
#   datamodels_rdf.Attribute & (datamodels_rdf.isPartialIdentifierForClass.some(<class 'int'>) | datamodels_rdf.isPartialIdentifierForClass.value(True))],
#  [datamodels_rdf.FunctionalPartialIdentifier, 9, datamodels_rdf.Attribute],
#  [datamodels_rdf.JobNode, 6, 11],
#  [datamodels_rdf.JobNode, 9, datamodels_rdf.DataLoad],
#  [datamodels_rdf.LogicalDataModel, 6, 11],
#  [datamodels_rdf.LogicalDataModel, 9, datamodels_rdf.Model],
#  [datamodels_rdf.LogicalEntityClass, 6, 11],
#  [datamodels_rdf.LogicalEntityClass, 9, datamodels_rdf.Class],
#  [datamodels_rdf.Mapping, 6, 11],
#  [datamodels_rdf.Mapping, 9, datamodels_rdf.SerializationSpecs],
#  [datamodels_rdf.MasterDataModel, 6, 11],
#  [datamodels_rdf.MasterDataModel, 9, datamodels_rdf.Model],
#  [datamodels_rdf.Meta, 6, 11],
#  [datamodels_rdf.Meta, 9, datamodels_rdf.SerializationMetaData],
#  [datamodels_rdf.MetaClass, 6, 11],
#  [datamodels_rdf.MetaClass, 9, datamodels_rdf.Meta],
#  [datamodels_rdf.MetaDataProperty, 6, 11],
#  [datamodels_rdf.MetaDataProperty, 9, datamodels_rdf.Meta],
#  [datamodels_rdf.MetaProperty, 6, 11],
#  [datamodels_rdf.MetaProperty, 9, datamodels_rdf.Meta],
#  [datamodels_rdf.Model, 6, 11],
#  [datamodels_rdf.Model, 9, datamodels_rdf.Definition],
#  [datamodels_rdf.ModelDomain, 6, 11],
#  [datamodels_rdf.ModelDomain, 9, datamodels_rdf.Definition],
#  [datamodels_rdf.PhysicalDataModel, 6, 11],
#  [datamodels_rdf.PhysicalDataModel, 9, datamodels_rdf.Model],
#  [datamodels_rdf.PhysicalEntityClass, 6, 11],
#  [datamodels_rdf.PhysicalEntityClass, 9, datamodels_rdf.Class],
#  [datamodels_rdf.PropertyMapping, 6, 11],
#  [datamodels_rdf.Mapping & datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaProperty),
#   6,
#   11],
#  [datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaProperty), 6, 17],
#  [datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaProperty),
#   18,
#   datamodels_rdf.MappingMetaTarget],
#  [datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaProperty),
#   24,
#   datamodels_rdf.MetaProperty],
#  [_:37, 3, datamodels_rdf.Mapping],
#  [_:37, 4, _:38],
#  [_:38, 3, datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaProperty)],
#  [_:38, 4, 5],
#  [datamodels_rdf.Mapping & datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaProperty),
#   31,
#   _:37],
#  [datamodels_rdf.PropertyMapping,
#   33,
#   datamodels_rdf.Mapping & datamodels_rdf.MappingMetaTarget.some(datamodels_rdf.MetaProperty)],
#  [datamodels_rdf.PropertyMapping, 9, datamodels_rdf.Mapping],
#  [datamodels_rdf.Relationship, 6, 11],
#  [datamodels_rdf.Relationship, 9, datamodels_rdf.Definition],
#  [datamodels_rdf.RowNode, 6, 11],
#  [datamodels_rdf.RowNode, 9, datamodels_rdf.DataLoad],
#  [datamodels_rdf.Serialization, 6, 11],
#  [datamodels_rdf.Serialization, 9, datamodels_rdf.SerializationSpecs],
#  [datamodels_rdf.SerializationMetaData, 6, 11],
#  [datamodels_rdf.SerializationSpecs, 6, 11],
#  [datamodels_rdf.SerializationSpecs, 9, datamodels_rdf.SerializationMetaData],
#  [datamodels_rdf.Attribute, 6, owl.NamedIndividual],
#  [datamodels_rdf.Attribute, 6, datamodels_rdf.MetaClass],
#  [datamodels_rdf.Cardinality, 6, owl.NamedIndividual],
#  [datamodels_rdf.Cardinality, 6, datamodels_rdf.MetaDataProperty],
#  [datamodels_rdf.Class, 6, owl.NamedIndividual],
#  [datamodels_rdf.Class, 6, datamodels_rdf.MetaClass],
#  [datamodels_rdf.Contains, 6, owl.NamedIndividual],
#  [datamodels_rdf.Contains, 6, datamodels_rdf.MetaProperty],
#  [datamodels_rdf.Context, 6, owl.NamedIndividual],
#  [datamodels_rdf.Context, 6, datamodels_rdf.MetaClass],
#  [datamodels_rdf.DataType, 6, owl.NamedIndividual],
#  [datamodels_rdf.DataType, 6, datamodels_rdf.MetaDataProperty],
#  [datamodels_rdf.EntityAttributeRecord, 6, owl.NamedIndividual],
#  [datamodels_rdf.EntityAttributeRecord, 6, datamodels_rdf.Serialization],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_Attribute],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_AttributeHasDataType],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_Class],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_ClassContainsAttribute],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_Context],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_ContextContainsClass],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_ContextContainsSubContext],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_DomainContainsModel],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_FromAttribute],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_FromClass],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_Model],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_ModelContainsClass],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_ModelContainsContext],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_ModelContainsRelationship],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_ModelDomain],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_ModelHasModelType],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_Relationship],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_RelationshipFromAttribute],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_RelationshipFromCardinality],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_RelationshipFromClass],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_RelationshipToAttribute],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_RelationshipToCardinality],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_RelationshipToClass],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_SubContext],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_ToAttribute],
#  [datamodels_rdf.EntityAttributeRecord,
#   datamodels_rdf.Contains,
#   datamodels_rdf.Mapping_ToClass],
#  [datamodels_rdf.FromCardinality, 6, owl.NamedIndividual],
#  [datamodels_rdf.FromCardinality, 6, datamodels_rdf.MetaDataProperty],
#  [datamodels_rdf.Mapping_Attribute, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_Attribute, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_Attribute,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Attribute],
#  [datamodels_rdf.Mapping_AttributeHasDataType, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_AttributeHasDataType, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_AttributeHasDataType,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.DataType],
#  [datamodels_rdf.Mapping_Class, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_Class, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_Class,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Class],
#  [datamodels_rdf.Mapping_ClassContainsAttribute, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_ClassContainsAttribute, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_ClassContainsAttribute,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_Context, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_Context, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_Context,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Context],
#  [datamodels_rdf.Mapping_ContextContainsClass, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_ContextContainsClass, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_ContextContainsClass,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_ContextContainsSubContext, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_ContextContainsSubContext, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_ContextContainsSubContext,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_DomainContainsModel, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_DomainContainsModel, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_DomainContainsModel,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_FromAttribute, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_FromAttribute, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_FromAttribute,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Attribute],
#  [datamodels_rdf.Mapping_FromClass, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_FromClass, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_FromClass,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Class],
#  [datamodels_rdf.Mapping_Model, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_Model, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_Model,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Model],
#  [datamodels_rdf.Mapping_ModelContainsClass, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_ModelContainsClass, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_ModelContainsClass,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_ModelContainsContext, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_ModelContainsContext, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_ModelContainsContext,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_ModelContainsRelationship, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_ModelContainsRelationship, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_ModelContainsRelationship,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_ModelDomain, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_ModelDomain, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_ModelDomain,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.ModelDomain],
#  [datamodels_rdf.Mapping_ModelHasModelType, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_ModelHasModelType, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_ModelHasModelType,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.ModelType],
#  [datamodels_rdf.Mapping_Relationship, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_Relationship, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_Relationship,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Relationship],
#  [datamodels_rdf.Mapping_RelationshipFromAttribute, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_RelationshipFromAttribute, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_RelationshipFromAttribute,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.RelationshipFromAttribute],
#  [datamodels_rdf.Mapping_RelationshipFromCardinality, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_RelationshipFromCardinality,
#   6,
#   datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_RelationshipFromCardinality,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.FromCardinality],
#  [datamodels_rdf.Mapping_RelationshipFromClass, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_RelationshipFromClass, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_RelationshipFromClass,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.RelationshipFromClass],
#  [datamodels_rdf.Mapping_RelationshipToAttribute, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_RelationshipToAttribute, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_RelationshipToAttribute,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.RelationshipToAttribute],
#  [datamodels_rdf.Mapping_RelationshipToCardinality, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_RelationshipToCardinality, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_RelationshipToCardinality,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.ToCardinality],
#  [datamodels_rdf.Mapping_RelationshipToClass, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_RelationshipToClass, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_RelationshipToClass,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.RelationshipToClass],
#  [datamodels_rdf.Mapping_SubContext, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_SubContext, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_SubContext,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Context],
#  [datamodels_rdf.Mapping_ToAttribute, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_ToAttribute, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_ToAttribute,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Attribute],
#  [datamodels_rdf.Mapping_ToClass, 6, owl.NamedIndividual],
#  [datamodels_rdf.Mapping_ToClass, 6, datamodels_rdf.Mapping],
#  [datamodels_rdf.Mapping_ToClass,
#   datamodels_rdf.MappingMetaTarget,
#   datamodels_rdf.Class],
#  [datamodels_rdf.MemberOf, 6, owl.NamedIndividual],
#  [datamodels_rdf.MemberOf, 6, datamodels_rdf.MetaProperty],
#  [datamodels_rdf.Model, 6, owl.NamedIndividual],
#  [datamodels_rdf.Model, 6, datamodels_rdf.MetaClass],
#  [datamodels_rdf.ModelDomain, 6, owl.NamedIndividual],
#  [datamodels_rdf.ModelDomain, 6, datamodels_rdf.MetaClass],
#  [datamodels_rdf.ModelType, 6, owl.NamedIndividual],
#  [datamodels_rdf.ModelType, 6, datamodels_rdf.MetaDataProperty],
#  [datamodels_rdf.Optionality, 6, owl.NamedIndividual],
#  [datamodels_rdf.Optionality, 6, datamodels_rdf.MetaDataProperty],
#  [datamodels_rdf.Relationship, 6, owl.NamedIndividual],
#  [datamodels_rdf.Relationship, 6, datamodels_rdf.MetaClass],
#  [datamodels_rdf.RelationshipFromAttribute, 6, owl.NamedIndividual],
#  [datamodels_rdf.RelationshipFromAttribute, 6, datamodels_rdf.MetaProperty],
#  [datamodels_rdf.RelationshipFromClass, 6, owl.NamedIndividual],
#  [datamodels_rdf.RelationshipFromClass, 6, datamodels_rdf.MetaProperty],
#  [datamodels_rdf.RelationshipRecord, 6, owl.NamedIndividual],
#  [datamodels_rdf.RelationshipRecord, 6, datamodels_rdf.Serialization],
#  [datamodels_rdf.RelationshipToAttribute, 6, owl.NamedIndividual],
#  [datamodels_rdf.RelationshipToAttribute, 6, datamodels_rdf.MetaProperty],
#  [datamodels_rdf.RelationshipToClass, 6, owl.NamedIndividual],
#  [datamodels_rdf.RelationshipToClass, 6, datamodels_rdf.MetaProperty],
#  [datamodels_rdf.ToCardinality, 6, owl.NamedIndividual],
#  [datamodels_rdf.ToCardinality, 6, datamodels_rdf.MetaDataProperty],
#  [AllDisjoint([datamodels_rdf.DataPropertyMapping, datamodels_rdf.EntityMapping, datamodels_rdf.PropertyMapping]),
#   6,
#   35],
#  [_:40, 3, datamodels_rdf.DataPropertyMapping],
#  [_:40, 4, _:41],
#  [_:41, 3, datamodels_rdf.EntityMapping],
#  [_:41, 4, _:42],
#  [_:42, 3, datamodels_rdf.PropertyMapping],
#  [_:42, 4, 5],
#  [AllDisjoint([datamodels_rdf.DataPropertyMapping, datamodels_rdf.EntityMapping, datamodels_rdf.PropertyMapping]),
#   37,
#   _:40],
#  [datamodels_rdf.ModelDomain, 6, datamodels_rdf.Definition],
#  [datamodels_rdf.Class, 6, datamodels_rdf.Definition],
#  [datamodels_rdf.Context, 6, datamodels_rdf.Definition],
#  [datamodels_rdf.Attribute, 6, datamodels_rdf.Definition],
#  [datamodels_rdf.Model, 6, datamodels_rdf.Definition],
#  [datamodels_rdf.Relationship, 6, datamodels_rdf.Definition],
#  [datamodels_rdf.ToCardinality, 6, datamodels_rdf.Cardinality],
#  [datamodels_rdf.FromCardinality, 6, datamodels_rdf.Cardinality],
#  [datamodels_rdf.Mapping_RelationshipFromAttribute,
#   6,
#   datamodels_rdf.PropertyMapping],
#  [datamodels_rdf.Mapping_Context, 6, datamodels_rdf.EntityMapping],
#  [datamodels_rdf.Mapping_ClassContainsAttribute,
#   6,
#   datamodels_rdf.PropertyMapping],
#  [datamodels_rdf.Mapping_ModelHasModelType,
#   6,
#   datamodels_rdf.DataPropertyMapping],
#  [datamodels_rdf.Mapping_ModelContainsRelationship,
#   6,
#   datamodels_rdf.PropertyMapping],
#  [datamodels_rdf.Mapping_Relationship, 6, datamodels_rdf.EntityMapping],
#  [datamodels_rdf.Mapping_RelationshipToAttribute,
#   6,
#   datamodels_rdf.PropertyMapping],
#  [datamodels_rdf.Mapping_FromClass, 6, datamodels_rdf.EntityMapping],
#  [datamodels_rdf.Mapping_Class, 6, datamodels_rdf.EntityMapping],
#  [datamodels_rdf.Mapping_ToAttribute, 6, datamodels_rdf.EntityMapping],
#  [datamodels_rdf.Mapping_Attribute, 6, datamodels_rdf.EntityMapping],
#  [datamodels_rdf.Mapping_Model, 6, datamodels_rdf.EntityMapping],
#  [datamodels_rdf.Mapping_RelationshipFromClass,
#   6,
#   datamodels_rdf.PropertyMapping],
#  [datamodels_rdf.Mapping_ModelDomain, 6, datamodels_rdf.EntityMapping],
#  [datamodels_rdf.Mapping_ModelContainsContext,
#   6,
#   datamodels_rdf.PropertyMapping],
#  [datamodels_rdf.Mapping_ContextContainsSubContext,
#   6,
#   datamodels_rdf.PropertyMapping],
#  [datamodels_rdf.Mapping_FromAttribute, 6, datamodels_rdf.EntityMapping],
#  [datamodels_rdf.Mapping_ToClass, 6, datamodels_rdf.EntityMapping],
#  [datamodels_rdf.Mapping_ModelContainsClass,
#   6,
#   datamodels_rdf.PropertyMapping],
#  [datamodels_rdf.Mapping_DomainContainsModel,
#   6,
#   datamodels_rdf.PropertyMapping],
#  [datamodels_rdf.Mapping_AttributeHasDataType,
#   6,
#   datamodels_rdf.DataPropertyMapping],
#  [datamodels_rdf.Mapping_RelationshipToCardinality,
#   6,
#   datamodels_rdf.DataPropertyMapping],
#  [datamodels_rdf.Mapping_ContextContainsClass,
#   6,
#   datamodels_rdf.PropertyMapping],
#  [datamodels_rdf.Mapping_RelationshipToClass,
#   6,
#   datamodels_rdf.PropertyMapping],
#  [datamodels_rdf.Mapping_SubContext, 6, datamodels_rdf.EntityMapping],
#  [datamodels_rdf.Mapping_RelationshipFromCardinality,
#   6,
#   datamodels_rdf.DataPropertyMapping],
#  [11.serialization, 6, owl.Ontology],
#  [Serialization.MappingMetaTarget, 6, owl.AnnotationProperty],
#  [Serialization.MappingMetaTarget, 8, Serialization.Meta],
#  [Serialization.ContainsMapping, 6, owl.ObjectProperty],
#  [Serialization.ContainsMapping, 16, Serialization.MappingMemberOf],
#  [Serialization.MappingMemberOf, 6, owl.ObjectProperty],
#  [Serialization.MappingMetaTarget, 6, owl.ObjectProperty],
#  [Serialization.MappingMetaTarget, 10, owl.topObjectProperty],
#  [Serialization.MappingMetaTarget, 7, Serialization.Mapping],
#  [Serialization.GeneratedOn, 6, owl.DatatypeProperty],
#  [Serialization.MappingDomain, 6, owl.DatatypeProperty],
#  [Serialization.MappingLabel, 6, owl.DatatypeProperty],
#  [Serialization.MappingRange, 6, owl.DatatypeProperty],
#  [Serialization.MappingSubType, 6, owl.DatatypeProperty],
#  [Serialization.SerializationLabel, 6, owl.DatatypeProperty],
#  [Serialization.SerializationParentLabel, 6, owl.DatatypeProperty],
#  [Serialization.BatchDefinition, 6, 11],
#  [Serialization.BatchDefinition, 9, Serialization.SerializationSpecs],
#  [Serialization.BatchNode, 6, 11],
#  [Serialization.BatchNode, 9, Serialization.DataLoad],
#  [Serialization.DataLoad, 6, 11],
#  [Serialization.DataLoad, 9, Serialization.SerializationMetaData],
#  [Serialization.DataPropertyMapping, 6, 11],
#  [Serialization.Mapping & Serialization.MappingMetaTarget.some(Serialization.MetaDataProperty),
#   6,
#   11],
#  [Serialization.MappingMetaTarget.some(Serialization.MetaDataProperty), 6, 17],
#  [Serialization.MappingMetaTarget.some(Serialization.MetaDataProperty),
#   18,
#   Serialization.MappingMetaTarget],
#  [Serialization.MappingMetaTarget.some(Serialization.MetaDataProperty),
#   24,
#   Serialization.MetaDataProperty],
#  [_:45, 3, Serialization.Mapping],
#  [_:45, 4, _:46],
#  [_:46,
#   3,
#   Serialization.MappingMetaTarget.some(Serialization.MetaDataProperty)],
#  [_:46, 4, 5],
#  [Serialization.Mapping & Serialization.MappingMetaTarget.some(Serialization.MetaDataProperty),
#   31,
#   _:45],
#  [Serialization.DataPropertyMapping,
#   33,
#   Serialization.Mapping & Serialization.MappingMetaTarget.some(Serialization.MetaDataProperty)],
#  [Serialization.DataPropertyMapping, 9, Serialization.Mapping],
#  [Serialization.EntityMapping, 6, 11],
#  [Serialization.Mapping & Serialization.MappingMetaTarget.some(Serialization.MetaClass),
#   6,
#   11],
#  [Serialization.MappingMetaTarget.some(Serialization.MetaClass), 6, 17],
#  [Serialization.MappingMetaTarget.some(Serialization.MetaClass),
#   18,
#   Serialization.MappingMetaTarget],
#  [Serialization.MappingMetaTarget.some(Serialization.MetaClass),
#   24,
#   Serialization.MetaClass],
#  [_:49, 3, Serialization.Mapping],
#  [_:49, 4, _:50],
#  [_:50, 3, Serialization.MappingMetaTarget.some(Serialization.MetaClass)],
#  [_:50, 4, 5],
#  [Serialization.Mapping & Serialization.MappingMetaTarget.some(Serialization.MetaClass),
#   31,
#   _:49],
#  [Serialization.EntityMapping,
#   33,
#   Serialization.Mapping & Serialization.MappingMetaTarget.some(Serialization.MetaClass)],
#  [Serialization.EntityMapping, 9, Serialization.Mapping],
#  [Serialization.JobNode, 6, 11],
#  [Serialization.JobNode, 9, Serialization.DataLoad],
#  [Serialization.Mapping, 6, 11],
#  [Serialization.Mapping, 9, Serialization.SerializationSpecs],
#  [Serialization.Meta, 6, 11],
#  [Serialization.Meta, 9, Serialization.SerializationMetaData],
#  [Serialization.MetaClass, 6, 11],
#  [Serialization.MetaClass, 9, Serialization.Meta],
#  [Serialization.MetaDataProperty, 6, 11],
#  [Serialization.MetaDataProperty, 9, Serialization.Meta],
#  [Serialization.MetaProperty, 6, 11],
#  [Serialization.MetaProperty, 9, Serialization.Meta],
#  [Serialization.PropertyMapping, 6, 11],
#  [Serialization.Mapping & Serialization.MappingMetaTarget.some(Serialization.MetaProperty),
#   6,
#   11],
#  [Serialization.MappingMetaTarget.some(Serialization.MetaProperty), 6, 17],
#  [Serialization.MappingMetaTarget.some(Serialization.MetaProperty),
#   18,
#   Serialization.MappingMetaTarget],
#  [Serialization.MappingMetaTarget.some(Serialization.MetaProperty),
#   24,
#   Serialization.MetaProperty],
#  [_:53, 3, Serialization.Mapping],
#  [_:53, 4, _:54],
#  [_:54, 3, Serialization.MappingMetaTarget.some(Serialization.MetaProperty)],
#  [_:54, 4, 5],
#  [Serialization.Mapping & Serialization.MappingMetaTarget.some(Serialization.MetaProperty),
#   31,
#   _:53],
#  [Serialization.PropertyMapping,
#   33,
#   Serialization.Mapping & Serialization.MappingMetaTarget.some(Serialization.MetaProperty)],
#  [Serialization.PropertyMapping, 9, Serialization.Mapping],
#  [Serialization.RowNode, 6, 11],
#  [Serialization.RowNode, 9, Serialization.DataLoad],
#  [Serialization.Serialization, 6, 11],
#  [Serialization.Serialization, 9, Serialization.SerializationSpecs],
#  [Serialization.SerializationMetaData, 6, 11],
#  [Serialization.SerializationSpecs, 6, 11],
#  [Serialization.SerializationSpecs, 9, Serialization.SerializationMetaData],
#  [AllDisjoint([Serialization.BatchDefinition, Serialization.Mapping, Serialization.Serialization]),
#   6,
#   35],
#  [_:56, 3, Serialization.BatchDefinition],
#  [_:56, 4, _:57],
#  [_:57, 3, Serialization.Mapping],
#  [_:57, 4, _:58],
#  [_:58, 3, Serialization.Serialization],
#  [_:58, 4, 5],
#  [AllDisjoint([Serialization.BatchDefinition, Serialization.Mapping, Serialization.Serialization]),
#   37,
#   _:56],
#  [AllDisjoint([Serialization.BatchNode, Serialization.JobNode, Serialization.RowNode]),
#   6,
#   35],
#  [_:60, 3, Serialization.BatchNode],
#  [_:60, 4, _:61],
#  [_:61, 3, Serialization.JobNode],
#  [_:61, 4, _:62],
#  [_:62, 3, Serialization.RowNode],
#  [_:62, 4, 5],
#  [AllDisjoint([Serialization.BatchNode, Serialization.JobNode, Serialization.RowNode]),
#   37,
#   _:60],
#  [AllDisjoint([Serialization.DataLoad, Serialization.Meta, Serialization.SerializationSpecs]),
#   6,
#   35],
#  [_:64, 3, Serialization.DataLoad],
#  [_:64, 4, _:65],
#  [_:65, 3, Serialization.Meta],
#  [_:65, 4, _:66],
#  [_:66, 3, Serialization.SerializationSpecs],
#  [_:66, 4, 5],
#  [AllDisjoint([Serialization.DataLoad, Serialization.Meta, Serialization.SerializationSpecs]),
#   37,
#   _:64],
#  [AllDisjoint([Serialization.DataPropertyMapping, Serialization.EntityMapping, Serialization.PropertyMapping]),
#   6,
#   35],
#  [_:68, 3, Serialization.DataPropertyMapping],
#  [_:68, 4, _:69],
#  [_:69, 3, Serialization.EntityMapping],
#  [_:69, 4, _:70],
#  [_:70, 3, Serialization.PropertyMapping],
#  [_:70, 4, 5],
#  [AllDisjoint([Serialization.DataPropertyMapping, Serialization.EntityMapping, Serialization.PropertyMapping]),
#   37,
#   _:68],
#  [AllDisjoint([Serialization.MetaClass, Serialization.MetaDataProperty, Serialization.MetaProperty]),
#   6,
#   35],
#  [_:72, 3, Serialization.MetaClass],
#  [_:72, 4, _:73],
#  [_:73, 3, Serialization.MetaDataProperty],
#  [_:73, 4, _:74],
#  [_:74, 3, Serialization.MetaProperty],
#  [_:74, 4, 5],
#  [AllDisjoint([Serialization.MetaClass, Serialization.MetaDataProperty, Serialization.MetaProperty]),
#   37,
#   _:72],
#  [datamodels_rdf.Mapping_ModelHasModelType,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.ModelType],
#  [datamodels_rdf.Mapping_ModelHasModelType, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_RelationshipToCardinality,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.ToCardinality],
#  [datamodels_rdf.Mapping_RelationshipToCardinality, 6, Serialization.Mapping],
#  [datamodels_rdf.RelationshipToClass, 6, datamodels_rdf.MetaProperty],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_FromAttribute],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_Relationship],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_ContextContainsSubContext],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_FromClass],
#  [datamodels_rdf.EntityAttributeRecord, 6, Serialization.Serialization],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_RelationshipFromCardinality],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_Model],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_ContextContainsClass],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_RelationshipFromClass],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_ModelHasModelType],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_ModelContainsRelationship],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_SubContext],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_ClassContainsAttribute],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_RelationshipToClass],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_RelationshipToAttribute],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_Context],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_ModelContainsClass],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_Attribute],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_ToAttribute],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_ModelContainsContext],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_RelationshipFromAttribute],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_DomainContainsModel],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_RelationshipToCardinality],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_ToClass],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_AttributeHasDataType],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_Class],
#  [datamodels_rdf.EntityAttributeRecord,
#   Serialization.ContainsMapping,
#   datamodels_rdf.Mapping_ModelDomain],
#  [datamodels_rdf.Mapping_FromAttribute,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Attribute],
#  [datamodels_rdf.Mapping_FromAttribute, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_Relationship,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Relationship],
#  [datamodels_rdf.Mapping_Relationship, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_RelationshipFromClass,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.RelationshipFromClass],
#  [datamodels_rdf.Mapping_RelationshipFromClass, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_ModelContainsClass, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_ModelContainsClass,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_RelationshipFromCardinality,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.FromCardinality],
#  [datamodels_rdf.Mapping_RelationshipFromCardinality,
#   6,
#   Serialization.Mapping],
#  [datamodels_rdf.Optionality, 6, datamodels_rdf.MetaDataProperty],
#  [datamodels_rdf.Mapping_SubContext,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Context],
#  [datamodels_rdf.Mapping_SubContext, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_Model, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_Model,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Model],
#  [datamodels_rdf.Mapping_RelationshipFromAttribute,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.RelationshipFromAttribute],
#  [datamodels_rdf.Mapping_RelationshipFromAttribute, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_ClassContainsAttribute,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_ClassContainsAttribute, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_ToClass, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_ToClass,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Class],
#  [datamodels_rdf.Mapping_ToAttribute, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_ToAttribute,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Attribute],
#  [datamodels_rdf.Mapping_ModelContainsContext, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_ModelContainsContext,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_Context, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_Context,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Context],
#  [datamodels_rdf.RelationshipToAttribute, 6, datamodels_rdf.MetaProperty],
#  [datamodels_rdf.Mapping_ContextContainsSubContext,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_ContextContainsSubContext, 6, Serialization.Mapping],
#  [datamodels_rdf.MemberOf, 6, datamodels_rdf.MetaProperty],
#  [datamodels_rdf.Mapping_ContextContainsClass, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_ContextContainsClass,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_ModelDomain,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.ModelDomain],
#  [datamodels_rdf.Mapping_ModelDomain, 6, Serialization.Mapping],
#  [datamodels_rdf.Relationship, 6, datamodels_rdf.MetaClass],
#  [datamodels_rdf.RelationshipFromClass, 6, datamodels_rdf.MetaProperty],
#  [datamodels_rdf.Mapping_DomainContainsModel,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_DomainContainsModel, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_AttributeHasDataType, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_AttributeHasDataType,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.DataType],
#  [datamodels_rdf.Attribute, 6, datamodels_rdf.MetaClass],
#  [datamodels_rdf.ModelDomain, 6, datamodels_rdf.MetaClass],
#  [datamodels_rdf.Mapping_RelationshipToAttribute, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_RelationshipToAttribute,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.RelationshipToAttribute],
#  [datamodels_rdf.Mapping_RelationshipToClass, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_RelationshipToClass,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.RelationshipToClass],
#  [datamodels_rdf.Mapping_ModelContainsRelationship,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Contains],
#  [datamodels_rdf.Mapping_ModelContainsRelationship, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_FromClass, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_FromClass,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Class],
#  [datamodels_rdf.RelationshipRecord, 6, Serialization.Serialization],
#  [datamodels_rdf.Mapping_Class, 6, Serialization.Mapping],
#  [datamodels_rdf.Mapping_Class,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Class],
#  [datamodels_rdf.Mapping_Attribute,
#   Serialization.MappingMetaTarget,
#   datamodels_rdf.Attribute],
#  [datamodels_rdf.Mapping_Attribute, 6, Serialization.Mapping],
#  [datamodels_rdf.Context, 6, datamodels_rdf.MetaClass],
#  [datamodels_rdf.Model, 6, datamodels_rdf.MetaClass],
#  [datamodels_rdf.Cardinality, 6, datamodels_rdf.MetaDataProperty],
#  [datamodels_rdf.RelationshipFromAttribute, 6, datamodels_rdf.MetaProperty],
#  [datamodels_rdf.Class, 6, datamodels_rdf.MetaClass],
#  [datamodels_rdf.ModelType, 6, datamodels_rdf.MetaDataProperty],
#  [datamodels_rdf.Contains, 6, datamodels_rdf.MetaProperty],
#  [datamodels_rdf.DataType, 6, datamodels_rdf.MetaDataProperty],
#  [datamodels_rdf.FromCardinality, 6, datamodels_rdf.MetaDataProperty],
#  [datamodels_rdf.ToCardinality, 6, datamodels_rdf.MetaDataProperty],
#  [.EntityAttributeRecord.rdf, 6, owl.Ontology],
#  [11.serialization, 81, .EntityAttributeRecord.rdf],
#  [discourse.Atom,
#   rdf-schema.comment,
#   'An Atom is a single constituatn element of a triple.'],
#  [discourse.DiscourseContains,
#   rdf-schema.comment,
#   'A Discourse is a hierarchical container, whose members can be other sub-discourses, or root-level Declarations.'],
#  [discourse.Posits,
#   rdf-schema.comment,
#   'A Declaration Posits some Posit. This relationship links the act of stating some posit, and the Posit itself. The same Posit can be Posited by multiple Declarations.'],
#  [discourse.Digest,
#   rdf-schema.comment,
#   "The Digest is a longform string representation of a triple, where each Atom is expressed in n3 notation, delimited by 3 tildes '~~~', and is normally assigned to a Posit."],
#  [discourse.GeneratedOn,
#   rdf-schema.comment,
#   'A DateTime value describing the datetime when the associated information was generated within the ontology.'],
#  [discourse.Declaration,
#   rdf-schema.comment,
#   'A Declaration is an instance of a posit being made at some point in time. It provides a context for when and how a posit might be repeatably referenced.\n\nThe posit that it might refer to is a platonic object, existing without time or context, so a Declaration is reference to the usage or expression of that posit that can be linked to some real world event.'],
#  [discourse.Discourse,
#   rdf-schema.comment,
#   'A Discourse is a collection of Declarations that might be considered as a set. These Declarations are linked to the Discourse via the DiscourseContains property.'],
#  [discourse.Interlocutor,
#   rdf-schema.comment,
#   'An Interlocutor is someone or something that has the capacity to Propose Declarations - either individually, or as part of a wider Discourse.'],
#  [discourse.Posit,
#   rdf-schema.comment,
#   "A Posit is a representation of a single piece of information that might be expressed as a semantic triple. It is a platonic object, in that it simply exists as a possibility, and doesn't possess any context."],
#  [_:6, 3, 'Many'],
#  [_:7, 3, 'One'],
#  [_:9, 3, 'Entity'],
#  [_:10, 3, 'Property'],
#  [_:12, 3, 'Mandatory'],
#  [_:13, 3, 'Optional'],
#  [datamodels_rdf.SerializationLabel,
#   rdf-schema.comment,
#   'The SerializationLabel is the label or value used as an attribute header in some serialised file used to populate or extract data from the ontology.'],
#  [datamodels_rdf.SerializationParentLabel,
#   rdf-schema.comment,
#   'For establishing unique IRIs within some kind of Hierarchy'],
#  [datamodels_rdf.UniqueIdentifier,
#   rdf-schema.comment,
#   'An Identifier is indended to be a unique name that distinguishes similarly named objects across different contexts.'],
#  [datamodels_rdf.isIdentifierForClass,
#   rdf-schema.comment,
#   'For attributes that can be used to uniquely identify members of this class, set to true.'],
#  [datamodels_rdf.isPartialIdentifierForClass,
#   rdf-schema.comment,
#   'Used for attributes that, in combination, are used as a unique identifier for the class.'],
#  [datamodels_rdf.AbstractClass,
#   core.definition,
#   'An Abstract is a type of class used to represent a single abstracted version of classes that might be present across multiple models or domains. Its use comes about as a result from the assumption that every class is unique to its given model. Multuple model-level classes are mapped to a single Abstract class inheriting all the model-level details.'],
#  [datamodels_rdf.BatchNode,
#   rdf-schema.comment,
#   'A BatchNode might contain multiple Serialization Job events - perhaps loading different sets of data under a single Batch.'],
#  [datamodels_rdf.ConceptClass,
#   core.definition,
#   'A concept in this context is a high level class describing some concept, idea or thing that is of interest to the business. Concepts form the nodes of a conceptual data model. Each model will consist of a unique set of concepts - so if two models reference a "user" concept, there would exist two versions of this, one per model - enabling an independence of definition.'],
#  [datamodels_rdf.Definition, rdf-schema.label, 'Definition'],
#  [datamodels_rdf.Definition,
#   core.definition,
#   'A definition is the description of some kind of representation.'],
#  [datamodels_rdf.isIdentifierForClass.value(True), 29, True],
#  [datamodels_rdf.isPartialIdentifierForClass.value(True), 29, True],
#  [datamodels_rdf.JobNode,
#   rdf-schema.comment,
#   'A JobNode is a unique node representing a single Serialization-specific data-load event. It would be expected to be associated with a Serialization Instance and a series of RowNodes.'],
#  [datamodels_rdf.LogicalEntityClass,
#   core.definition,
#   'A logical entity describes some business concept, defining a series of attributes commonly associated with it. Entities form the nodes of logical and physical data models.'],
#  [datamodels_rdf.Mapping,
#   core.definition,
#   'A mapping contains all the information required to interpret content on a row of data and convert it into an individual in the ontology.\n\nSome mappings relate to entity creation, while others describe relations - relation-describing mappings are Inferred to be PropertyMappings by virtue of their possession of both MappingRange and MappingDomain data properties.'],
#  [datamodels_rdf.MetaClass,
#   core.definition,
#   'A Class of objects whose individuals represent Classes within the Ontology using the convention of "punning" - such individuals share the exact same names as the classes they represent.'],
#  [datamodels_rdf.MetaDataProperty,
#   core.definition,
#   'A Class of objects whose individuals represent DataProperties within the Ontology using the convention of "punning" - such individuals share the exact same names as the Data Properties they represent.'],
#  [datamodels_rdf.MetaProperty,
#   core.definition,
#   'A Class of objects whose individuals represent Object Properties within the Ontology using the convention of "punning" - such individuals share the exact same names as the Object Properties they represent.'],
#  [datamodels_rdf.PhysicalEntityClass,
#   core.definition,
#   'A physical entity describes some business concept, defining a series of attributes commonly associated with it. Entities form the nodes of logical and physical data models.'],
#  [datamodels_rdf.RowNode,
#   rdf-schema.comment,
#   'A row node is a unique node describing all content derived from an individual row in a data-load process. All objects generated from this row will be pointed to using the RowNodeParticipant property.'],
#  [datamodels_rdf.Serialization,
#   rdf-schema.comment,
#   "A serialization is a specification for mapping of data into the ontology's object model. An initial serialization is provided for use with instantiating content for the model, but it's anticipated that additional serializations be defined for alternate use-cases."],
#  [datamodels_rdf.Mapping_Attribute,
#   datamodels_rdf.SerializationLabel,
#   'Attribute'],
#  [datamodels_rdf.Mapping_Attribute,
#   datamodels_rdf.SerializationParentLabel,
#   'Class'],
#  [datamodels_rdf.Mapping_AttributeHasDataType,
#   datamodels_rdf.MappingDomain,
#   'Attribute'],
#  [datamodels_rdf.Mapping_AttributeHasDataType,
#   datamodels_rdf.MappingRange,
#   'DataType'],
#  [datamodels_rdf.Mapping_Class, datamodels_rdf.SerializationLabel, 'Class'],
#  [datamodels_rdf.Mapping_Class,
#   datamodels_rdf.SerializationParentLabel,
#   'Model'],
#  [datamodels_rdf.Mapping_ClassContainsAttribute,
#   datamodels_rdf.MappingDomain,
#   'Class'],
#  [datamodels_rdf.Mapping_ClassContainsAttribute,
#   datamodels_rdf.MappingRange,
#   'Attribute'],
#  [datamodels_rdf.Mapping_Context,
#   datamodels_rdf.SerializationLabel,
#   'Context'],
#  [datamodels_rdf.Mapping_Context,
#   datamodels_rdf.SerializationParentLabel,
#   'Model'],
#  [datamodels_rdf.Mapping_ContextContainsClass,
#   datamodels_rdf.MappingDomain,
#   'Context'],
#  [datamodels_rdf.Mapping_ContextContainsClass,
#   datamodels_rdf.MappingRange,
#   'Class'],
#  [datamodels_rdf.Mapping_ContextContainsSubContext,
#   datamodels_rdf.MappingDomain,
#   'Context'],
#  [datamodels_rdf.Mapping_ContextContainsSubContext,
#   datamodels_rdf.MappingRange,
#   'SubContext'],
#  [datamodels_rdf.Mapping_DomainContainsModel,
#   datamodels_rdf.MappingDomain,
#   'ModelDomain'],
#  [datamodels_rdf.Mapping_DomainContainsModel,
#   datamodels_rdf.MappingRange,
#   'Model'],
#  [datamodels_rdf.Mapping_FromAttribute,
#   datamodels_rdf.SerializationLabel,
#   'FromAttribute'],
#  [datamodels_rdf.Mapping_FromAttribute,
#   datamodels_rdf.SerializationParentLabel,
#   'FromClass'],
#  [datamodels_rdf.Mapping_FromClass,
#   datamodels_rdf.SerializationLabel,
#   'FromClass'],
#  [datamodels_rdf.Mapping_FromClass,
#   datamodels_rdf.SerializationParentLabel,
#   'Model'],
#  [datamodels_rdf.Mapping_Model, datamodels_rdf.SerializationLabel, 'Model'],
#  [datamodels_rdf.Mapping_Model,
#   datamodels_rdf.SerializationParentLabel,
#   'ModelDomain'],
#  [datamodels_rdf.Mapping_ModelContainsClass,
#   datamodels_rdf.MappingDomain,
#   'Model'],
#  [datamodels_rdf.Mapping_ModelContainsClass,
#   datamodels_rdf.MappingRange,
#   'Class'],
#  [datamodels_rdf.Mapping_ModelContainsContext,
#   datamodels_rdf.MappingDomain,
#   'Model'],
#  [datamodels_rdf.Mapping_ModelContainsContext,
#   datamodels_rdf.MappingRange,
#   'Context'],
#  [datamodels_rdf.Mapping_ModelContainsRelationship,
#   datamodels_rdf.MappingDomain,
#   'Model'],
#  [datamodels_rdf.Mapping_ModelContainsRelationship,
#   datamodels_rdf.MappingRange,
#   'Relationship'],
#  [datamodels_rdf.Mapping_ModelDomain,
#   datamodels_rdf.SerializationLabel,
#   'ModelDomain'],
#  [datamodels_rdf.Mapping_ModelHasModelType,
#   datamodels_rdf.MappingDomain,
#   'Model'],
#  [datamodels_rdf.Mapping_ModelHasModelType,
#   datamodels_rdf.MappingRange,
#   'ModelType'],
#  [datamodels_rdf.Mapping_Relationship,
#   datamodels_rdf.SerializationLabel,
#   'Relationship'],
#  [datamodels_rdf.Mapping_Relationship,
#   datamodels_rdf.SerializationParentLabel,
#   'Model'],
#  [datamodels_rdf.Mapping_RelationshipFromAttribute,
#   datamodels_rdf.MappingDomain,
#   'Relationship'],
#  [datamodels_rdf.Mapping_RelationshipFromAttribute,
#   datamodels_rdf.MappingRange,
#   'FromAttribute'],
#  [datamodels_rdf.Mapping_RelationshipFromCardinality,
#   datamodels_rdf.MappingDomain,
#   'Relationship'],
#  [datamodels_rdf.Mapping_RelationshipFromCardinality,
#   datamodels_rdf.MappingRange,
#   'FromCardinality'],
#  [datamodels_rdf.Mapping_RelationshipFromClass,
#   datamodels_rdf.MappingDomain,
#   'Relationship'],
#  [datamodels_rdf.Mapping_RelationshipFromClass,
#   datamodels_rdf.MappingRange,
#   'FromClass'],
#  [datamodels_rdf.Mapping_RelationshipToAttribute,
#   datamodels_rdf.MappingDomain,
#   'Relationship'],
#  [datamodels_rdf.Mapping_RelationshipToAttribute,
#   datamodels_rdf.MappingRange,
#   'ToAttribute'],
#  [datamodels_rdf.Mapping_RelationshipToCardinality,
#   datamodels_rdf.MappingDomain,
#   'Relationship'],
#  [datamodels_rdf.Mapping_RelationshipToCardinality,
#   datamodels_rdf.MappingRange,
#   'ToCardinality'],
#  [datamodels_rdf.Mapping_RelationshipToClass,
#   datamodels_rdf.MappingDomain,
#   'Relationship'],
#  [datamodels_rdf.Mapping_RelationshipToClass,
#   datamodels_rdf.MappingRange,
#   'ToClass'],
#  [datamodels_rdf.Mapping_SubContext,
#   datamodels_rdf.SerializationLabel,
#   'SubContext'],
#  [datamodels_rdf.Mapping_SubContext,
#   datamodels_rdf.SerializationParentLabel,
#   'Model'],
#  [datamodels_rdf.Mapping_ToAttribute,
#   datamodels_rdf.SerializationLabel,
#   'ToAttribute'],
#  [datamodels_rdf.Mapping_ToAttribute,
#   datamodels_rdf.SerializationParentLabel,
#   'ToClass'],
#  [datamodels_rdf.Mapping_ToClass,
#   datamodels_rdf.SerializationLabel,
#   'ToClass'],
#  [datamodels_rdf.Mapping_ToClass,
#   datamodels_rdf.SerializationParentLabel,
#   'Model'],
#  [datamodels_rdf.Contains,
#   core.definition,
#   "Contains describes the object that is analogous to a set, in any set/element relationship. A Contains B is the inverse of B MemberOf A. It is not possible for an object to contain itself, nor can a Container's Member Contain the Container."],
#  [datamodels_rdf.Context, rdf-schema.label, 'Context'],
#  [datamodels_rdf.Context,
#   core.definition,
#   'A context is some grouping of entities, schema or concepts. In physical data models, this might describe an IBM DB2 or Oracle schema (i.e. a collection of tables, views and other objects into an administrative package), an application or a collection of datasets. For logical or conceptual models, it would be used to form an informal grouping within a larger model. For more formal groupings, expect to use Domain, or Model.'],
#  [datamodels_rdf.ModelDomain, rdf-schema.label, 'ModelDomain'],
#  [datamodels_rdf.Mapping_ModelHasModelType,
#   Serialization.MappingRange,
#   'ModelType'],
#  [datamodels_rdf.Mapping_ModelHasModelType,
#   Serialization.MappingDomain,
#   'Model'],
#  [datamodels_rdf.Mapping_RelationshipToCardinality,
#   Serialization.MappingDomain,
#   'Relationship'],
#  [datamodels_rdf.Mapping_RelationshipToCardinality,
#   Serialization.MappingRange,
#   'ToCardinality'],
#  [datamodels_rdf.Mapping_FromAttribute,
#   Serialization.SerializationParentLabel,
#   'FromClass'],
#  [datamodels_rdf.Mapping_FromAttribute,
#   Serialization.SerializationLabel,
#   'FromAttribute'],
#  [datamodels_rdf.Mapping_Relationship,
#   Serialization.SerializationLabel,
#   'Relationship'],
#  [datamodels_rdf.Mapping_Relationship,
#   Serialization.SerializationParentLabel,
#   'Model'],
#  [datamodels_rdf.Mapping_RelationshipFromClass,
#   Serialization.MappingRange,
#   'FromClass'],
#  [datamodels_rdf.Mapping_RelationshipFromClass,
#   Serialization.MappingDomain,
#   'Relationship'],
#  [datamodels_rdf.Mapping_ModelContainsClass,
#   Serialization.MappingRange,
#   'Class'],
#  [datamodels_rdf.Mapping_ModelContainsClass,
#   Serialization.MappingDomain,
#   'Model'],
#  [datamodels_rdf.Mapping_RelationshipFromCardinality,
#   Serialization.MappingRange,
#   'FromCardinality'],
#  [datamodels_rdf.Mapping_RelationshipFromCardinality,
#   Serialization.MappingDomain,
#   'Relationship'],
#  [datamodels_rdf.Mapping_SubContext,
#   Serialization.SerializationLabel,
#   'SubContext'],
#  [datamodels_rdf.Mapping_SubContext,
#   Serialization.SerializationParentLabel,
#   'Model'],
#  [datamodels_rdf.Mapping_Model,
#   Serialization.SerializationParentLabel,
#   'ModelDomain'],
#  [datamodels_rdf.Mapping_Model, Serialization.SerializationLabel, 'Model'],
#  [datamodels_rdf.Mapping_RelationshipFromAttribute,
#   Serialization.MappingDomain,
#   'Relationship'],
#  [datamodels_rdf.Mapping_RelationshipFromAttribute,
#   Serialization.MappingRange,
#   'FromAttribute'],
#  [datamodels_rdf.Mapping_ClassContainsAttribute,
#   Serialization.MappingRange,
#   'Attribute'],
#  [datamodels_rdf.Mapping_ClassContainsAttribute,
#   Serialization.MappingDomain,
#   'Class'],
#  [datamodels_rdf.Mapping_ToClass, Serialization.SerializationLabel, 'ToClass'],
#  [datamodels_rdf.Mapping_ToClass,
#   Serialization.SerializationParentLabel,
#   'Model'],
#  [datamodels_rdf.Mapping_ToAttribute,
#   Serialization.SerializationParentLabel,
#   'ToClass'],
#  [datamodels_rdf.Mapping_ToAttribute,
#   Serialization.SerializationLabel,
#   'ToAttribute'],
#  [datamodels_rdf.Mapping_ModelContainsContext,
#   Serialization.MappingRange,
#   'Context'],
#  [datamodels_rdf.Mapping_ModelContainsContext,
#   Serialization.MappingDomain,
#   'Model'],
#  [datamodels_rdf.Mapping_Context, Serialization.SerializationLabel, 'Context'],
#  [datamodels_rdf.Mapping_Context,
#   Serialization.SerializationParentLabel,
#   'Model'],
#  [datamodels_rdf.Mapping_ContextContainsSubContext,
#   Serialization.MappingDomain,
#   'Context'],
#  [datamodels_rdf.Mapping_ContextContainsSubContext,
#   Serialization.MappingRange,
#   'SubContext'],
#  [datamodels_rdf.Mapping_ContextContainsClass,
#   Serialization.MappingDomain,
#   'Context'],
#  [datamodels_rdf.Mapping_ContextContainsClass,
#   Serialization.MappingRange,
#   'Class'],
#  [datamodels_rdf.Mapping_ModelDomain,
#   Serialization.SerializationLabel,
#   'ModelDomain'],
#  [datamodels_rdf.Mapping_DomainContainsModel,
#   Serialization.MappingDomain,
#   'ModelDomain'],
#  [datamodels_rdf.Mapping_DomainContainsModel,
#   Serialization.MappingRange,
#   'Model'],
#  [datamodels_rdf.Mapping_AttributeHasDataType,
#   Serialization.MappingRange,
#   'DataType'],
#  [datamodels_rdf.Mapping_AttributeHasDataType,
#   Serialization.MappingDomain,
#   'Attribute'],
#  [datamodels_rdf.Mapping_RelationshipToAttribute,
#   Serialization.MappingDomain,
#   'Relationship'],
#  [datamodels_rdf.Mapping_RelationshipToAttribute,
#   Serialization.MappingRange,
#   'ToAttribute'],
#  [datamodels_rdf.Mapping_RelationshipToClass,
#   Serialization.MappingDomain,
#   'Relationship'],
#  [datamodels_rdf.Mapping_RelationshipToClass,
#   Serialization.MappingRange,
#   'ToClass'],
#  [datamodels_rdf.Mapping_ModelContainsRelationship,
#   Serialization.MappingDomain,
#   'Model'],
#  [datamodels_rdf.Mapping_ModelContainsRelationship,
#   Serialization.MappingRange,
#   'Relationship'],
#  [datamodels_rdf.Mapping_FromClass,
#   Serialization.SerializationParentLabel,
#   'Model'],
#  [datamodels_rdf.Mapping_FromClass,
#   Serialization.SerializationLabel,
#   'FromClass'],
#  [datamodels_rdf.Mapping_Class,
#   Serialization.SerializationParentLabel,
#   'Model'],
#  [datamodels_rdf.Mapping_Class, Serialization.SerializationLabel, 'Class'],
#  [datamodels_rdf.Mapping_Attribute,
#   Serialization.SerializationParentLabel,
#   'Class'],
#  [datamodels_rdf.Mapping_Attribute,
#   Serialization.SerializationLabel,
#   'Attribute']]

# %%
job_def_load_entities = ("Model Load", ser_onto.EntityAttributeRecord , serial_key, get_data_rows("model_entities.csv")  )
batch_manifest = [job_def_load_entities]

# %%
graph = loader.spawn_rdflib_graph()

# %%
graph = loader.load_data("Model Entities", batch_manifest=batch_manifest, rdflib_graph=graph)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-f6ee046197a3> in <module>
# ----> 1 graph = loader.load_data("Model Entities", batch_manifest=batch_manifest, rdflib_graph=graph)
#
# ~/Documents/Coding/gitHub/datamodels/loader.py in load_data(batch_name, batch_manifest, rdflib_graph)
#     214             for t in row_header.to_triples():
#     215                 working_graph.add(t)
# --> 216             raw_row_triples = serialize_row(c_row, serial_choice)
#     217             #print("r", len(raw_row_triples))
#     218
#
# ~/Documents/Coding/gitHub/datamodels/loader.py in serialize_row(row, serialization)
#     143
#     144 def serialize_row(row, serialization):
# --> 145     entity_mappings = onto_get_contents_matching_subclass(serialization, onto.EntityMapping)
#     146     data_property_mappings = onto_get_contents_matching_subclass(serialization, onto.DataPropertyMapping)
#     147     property_mappings = onto_get_contents_matching_subclass(serialization, onto.PropertyMapping)
#
# ~/Documents/Coding/gitHub/datamodels/loader.py in get_contents_matching_subclass(s, subclass)
#     307     if not isinstance(subclass, list):
#     308         subclass = [subclass]
# --> 309     for m in s.Contains:
#     310         if any([(c in subclass or x in subclass) for c in m.is_a for x in m.is_a.first().is_a]):
#     311             m_list.append(m)
#
# AttributeError: 'NoneType' object has no attribute 'Contains'

# %%
a,b,c,d = batch_manifest[0]

# %%
d
# Out:
# [{'ID': 0,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Person',
#   'Attribute': 'PersonID',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 1,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Person',
#   'Attribute': 'FirstName',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 2,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Person',
#   'Attribute': 'FamilyName',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 3,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Person',
#   'Attribute': 'DateOfBirth',
#   'DataType': 'date',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 4,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Person',
#   'Attribute': 'DateOfDeath',
#   'DataType': 'date',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 5,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Address',
#   'Attribute': 'Address Line 1',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 6,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Address',
#   'Attribute': 'Address Line 2',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 7,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Address',
#   'Attribute': 'Address Line 3',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 8,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Address',
#   'Attribute': 'Postal Code',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 9,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Address',
#   'Attribute': 'Country',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 10,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Address',
#   'Attribute': 'Country',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 11,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Insurance Product',
#   'Attribute': 'Coverage Type',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 12,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Insurance Policy',
#   'Attribute': 'Policy ID',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 13,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Insurance Policy',
#   'Attribute': 'Start Date',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 14,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Insurance Policy',
#   'Attribute': 'End Date',
#   'DataType': 'string',
#   'Context': None,
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 15,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': 'Insurance Policy',
#   'Attribute': None,
#   'DataType': None,
#   'Context': 'Policy Types',
#   'SubContext': None,
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 16,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': None,
#   'Attribute': None,
#   'DataType': None,
#   'Context': 'All Types',
#   'SubContext': 'Policy Types',
#   'Relationship': None,
#   'Entity From': None,
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': None,
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 16,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': None,
#   'Attribute': None,
#   'DataType': None,
#   'Context': None,
#   'SubContext': None,
#   'Relationship': 'hasPolicy',
#   'Entity From': 'Person',
#   'Attribute From': 'PersonID',
#   'Cardinality From': 'One',
#   'Entity To': 'Insurance Policy',
#   'Attribute To': 'Policy ID',
#   'Cardinality To': 'Many'},
#  {'ID': 17,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': None,
#   'Attribute': None,
#   'DataType': None,
#   'Context': None,
#   'SubContext': None,
#   'Relationship': 'ResidesAt',
#   'Entity From': 'Person',
#   'Attribute From': None,
#   'Cardinality From': None,
#   'Entity To': 'Address',
#   'Attribute To': None,
#   'Cardinality To': None},
#  {'ID': 18,
#   'Business Domain': 'Core',
#   'Model': 'Principal Interactions',
#   'ModelType': 'Conceptual',
#   'Entity': None,
#   'Attribute': None,
#   'DataType': None,
#   'Context': None,
#   'SubContext': None,
#   'Relationship': 'ConveysProduct',
#   'Entity From': 'Insurance Policy',
#   'Attribute From': None,
#   'Cardinality From': 'One',
#   'Entity To': 'Insurance Product',
#   'Attribute To': None,
#   'Cardinality To': 'One'}]
